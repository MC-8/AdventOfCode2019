# %%
from itertools import permutations
from collections import namedtuple, deque
from copy import deepcopy

def get_reachable_keys(owned_keys, key_dependencies):
    reachable_keys = set()
    for k in key_dependencies.keys():
        if key_dependencies[k].issubset(owned_keys):
            reachable_keys.add(k)
    # Purge owned keys from reachable keys
    #if reachable_keys.intersection(owned_keys):
    for k in reachable_keys.intersection(owned_keys):
        reachable_keys.remove(k)
    return reachable_keys

def get_visible_keys(owned_keys, key_dependencies):
    visible_keys = set()
    for k in key_dependencies.keys():
        if key_dependencies[k].issubset(owned_keys):
            visible_keys.add(k)
    # Purge owned keys from visible keys
    #if visible_keys.intersection(owned_keys):
    for k in visible_keys.intersection(owned_keys):
        visible_keys.remove(k)
    return visible_keys

char_maze = ["#########",
             "#b.A.@.a#",
             "#########"]

char_maze = ["########################",
             "#f.D.E.e.C.b.A.@.a.B.c.#",
             "######################.#",
             "#d.....................#",
             "########################"]

char_maze = ["########################",
             "#...............b.C.D.f#",
             "#.######################",
             "#.....@.a.B.c.d.A.e.F.g#",
             "########################"]

char_maze = ["#################", # Hard one, is a bit slow
             "#i.G..c...e..H.p#",
             "########.########",
             "#j.A..b...f..D.o#",
             "########@########",
             "#k.E..a...g..B.n#",
             "########.########",
             "#l.F..d...h..C.m#",
             "#################"]

char_maze = ["########################",
             "#@..............ac.GI.b#",
             "###d#e#f################",
             "###A#B#C################",
             "###g#h#i################",
             "########################"]

char_maze = ["#################################################################################",
             "#...#.....#......c....#...#.Q.......#...#f#a....#..j..........#...............#.#",
             "#.#.#.#.###.#######.#.#.#.#.###.###.#.#.#.#.###.#.#######.###.#.#.###########.#.#",
             "#.#.#v#.....#.....#.#...#.#.#...#...#.#.#.#...#.......#...#.#.#.#...#...#.....N.#",
             "###.#.#######.###.#X#######.#.###.###.###.###.#########R###.#.#.###.#.#.#.#######",
             "#.K.#.....#...#...#.....#...#.#.....#...#.....#.......#.#.#...#...#.#.#.#...#...#",
             "#.#.#####.#.###.#######.#.###.#####.#.#.#.#####.#####.#.#.#.#####.#.#.#.#####.#.#",
             "#.#.#.U.#.#.#...#...#...#...#...#...#.#.#.#...#.#...#...#.#.....#.#...#.......#.#",
             "#.#.###.#.#.#.#####.#.#.###.###.#.#####.#.#.#.#.###.#####.#####.#####.#####.###.#",
             "#.#.#...#...#.....#.#.#...#.#.#.#.....#.#.#.#.#.Y.#.....#.....#.....#.#...#...#.#",
             "#.#.#.#.#########.#.#.#####.#.#.#####.#.#.###.###.###.#.###.#.#####.###.#.#####.#",
             "#.#...#.#.........#.#.........#.#...#...#.#...#...#...#.#...#.#...#...#.#.......#",
             "#.#######.#########.###########.###.###.#.#.###.###.###.#.###.###.###.#.#######.#",
             "#.....#...#.#...........#.......#.....#.#...#...#.#...#...#.........#.#.#...#...#",
             "#.###.#.###.#.#########.#.#######.#####.#####.###.#.#.###############.#.#.#.#.###",
             "#.#.#.#...#.....#.......#.#.............#.....#.....#.....#.....#...#.#...#.#...#",
             "#.#.#.###.#####.#.#######.#.#####.#####.#.#####.#####.###.#.###.#.#.#.#.###.#####",
             "#.#.#...#.O...#.#.#.......#.#...#.#...#.#...#...#...#...#...#...#.#...#...#.....#",
             "#.#.#.#######.###.#.#####.###.#.#.#.#.#.#.#.#####.#.###.#####.###.#######.#####.#",
             "#.#.#.......#.....#.....#t#...#.#.#.#.#.#.#.#.....#.#.......#.....#.....#.#.....#",
             "#.#.#####.#######.#####.###.###.###.#.#.###.#.#####.###########.###.###.###.###.#",
             "#.......#.........#...#...#.#.#.....#.#.#...#.....#.#.....#...#.....#...#...#.#.#",
             "#######.###########.#####.#.#.#######.#.#.#####.###.#.###.#.###.#####.###.###.#.#",
             "#.......#.......#...#...#.#...#...#...#.#.#.....#...#.#.#.#...#.#...#.....#.#...#",
             "#.#####.#.#######.###.#.#.###.#.###.#####.#.#####.###.#.#.###.###.#.#.#####.#.###",
             "#.#...#...#...#...#...#.#.#...#...#.....#...#...#.......#...#...#.#.#.#...#...#.#",
             "#.#.#.#####.#.#.###.###.#.#.#####.#####.#P###.#.#######.###.###.#.#.###.#.###.#.#",
             "#.#.#.......#...#...#.....#.#.....#...#.#.#i..#...#...#.#.....#...#.#...#...#...#",
             "###.###############.#######.#.#.#.###.#.#.#####.###.#.###.#########.#.#####.###.#",
             "#...#.............#...#...#.#.#.#.#...#.#.....#.#...#.....#.......#.#...#...#.#.#",
             "#.###.#######.###.#.#.#.#.#.###.#.#.#.#.#####.#.#.#.#######.#####.#.###.###.#.#.#",
             "#.#.........#.#...#.#...#.......#...#.#.#.....#.#.#.#...#...#...#.#...#...#.#.#.#",
             "#.###########.#.###.###############.###.#.#####.#.###.#.#.###.###.###.###.#.#.#Z#",
             "#...#.........#.#.#.#.#.......#.....#...#.#.....#.#...#...#...#.....#.....#.#...#",
             "###.#.#########.#.#.#.#.#####.#.#####.#.#.###.###.#.#########.#.###.#######.#.###",
             "#.#...#.....#...#.#...#.#...#.#...#...#.#.#...#...#.#.......#.#...#.#.......#.#.#",
             "#.#####.#.###.###.###.#.#.#.#.#####.###.#.#.###.#.#.###.###.#.###.#.#.#######.#.#",
             "#.....#.#...#.#.......#...#.#.#...#.#...#.#.#...#.#.....#...#...#.#.#.#.....#..x#",
             "#.#####.###.#.#############.#.#.#.#.#.###.#.#.###########.###.#.#.###.#.#.#####.#",
             "#.........#.................#...#...#.......#.................#.#.....#.#.......#",
             "#######################################.@.#######################################",
             "#.......#.................#...............#.....#...........#.........#...#.....#",
             "#.#####.#.#########.#####.#.###########.#.#.###.#.#.#######.#.#.#######.#.###.#.#",
             "#...#.#.#.#...#...#.....#.#...#...#.....#.#...#...#.....#...#.#...#.....#.#...#.#",
             "###.#.#.###.#.#.#.#####.#.#####.#.#.###.#.###.#########.#####.###.#.#####.#V#####",
             "#...#.#...#.#.#.#.....#.#.#.....#.#.#...#...#.#.....#.#.....#...#...#...#.#.....#",
             "#.###.###.#.#.#.#####.#.#.#.#####.#.#.###.###.#.#.#.#.#####.###.#######.#.#####.#",
             "#...#...#.#.#.#.....#...#.#.#.....#.#...#.#...#.#.#.W.#...#...#.........#.....#.#",
             "#.#.###.#G#.#.#####.#####.#.#.#####.#####.#.#####.###.###.###.#####.#########.#.#",
             "#.#.#...#...#.#.....#...#...#.#.........#...#...#...#.......#.....#.#.....#...#.#",
             "###.#.#######.#.#######.#####.#.#######.#.###.#.###.#######.#.#####.#.###.#.###.#",
             "#...#.#.....#...#...........#.#.....#...#p....#...#.....#...#......r#.#.....#...#",
             "#.###.#.#.#######.###.#.#####.#.#####.#.#########.#.###.#E###########.#######.#.#",
             "#.#.....#.#.........#.#.#...#.#.#.....#.#...#...#.#.#...#...#.S.....#...#.....#.#",
             "#.#######.#.#########.#.#.#.#.#.#.#######.###.#.#.#.#.#####.###.#######.#.###.###",
             "#.L.....#.#z....#.....#.#.#.#.#.#...#...#.#...#...#.#.#.........#.......#.#.#...#",
             "#.#####.#.#####.#.#####.#.#.#.#####.#.#.#.#.#########.#.#########.#######.#.###.#",
             "#.#...#.#...#...#.....#.#.#...#.....#.#.#.#.......#...#.#...#.....#.#..o#.#.#...#",
             "#.#.###.###.#.#######.###.#####.#####.#.#.#######.#.###.#.#.#.#####.#.#.#.#.#.###",
             "#.#.#...#...#.......#...#.#.#...I.....#.#...#...#.#...#...#b#.#.......#.#...#...#",
             "#.#.#.###.#####.#######.#.#.#.#########.#.#.###.#.###.#######.#.#######.###.###.#",
             "#.#.#.#.#.......#.....#.#.#......y..#.#.#.#.....#...#...#...#.#..l#..g#.#.....#.#",
             "#.#.#.#.#.#######H#####.#.###.#####.#.#.#.###.#####.#.#.#.#.#####.#.#.#.#.#####.#",
             "#...#.#.#...#...#.#..h#.#...#.#...#...#.#.#...#.....#.#.#.#.....#.#.#.#.#.#.#...#",
             "#.###.#.###.#.#.#.#.#.#.###.###.#.#####.#.#####.#######.#.###.#.#.#.#.#.#.#.#.#.#",
             "#.#...#.......#.#...#.#.....#...#...#...#...#...#.....#.#...#.#.#.#.#...#...#.#.#",
             "#.#.###########.#####D#####.#.#####.#.#.#.#.#.###.###.#.###.#.#.#.#.#######.#.#.#",
             "#.#.#.....#.......#.#.....#...#.....#.#.#.#.#.#...#...#.....#.#.#.#...#.....#.#.#",
             "#M#.#.###.#######.#.#####.#####.#####.#####.#.#.###.###.#####.###.###.#.#####.#.#",
             "#.#.....#.#.....#.......#...#.#.#.......#...#...#...#...#...#.......#...#...#.#.#",
             "#.#######.#.###.#.#########.#A#.###.###.#.#######.#######.#.#.###########.#.#.#.#",
             "#.#w....#.#...#.#.#....d....#.#...#...#.#.......#...#...#.#.#..m#.....#...#...#.#",
             "#.#.###.#.###.#.###.#########.###.#####.#.###.#####.#.#.#.#.###.#.###.#.#######.#",
             "#k#...#.#u#...#...B.#.....#.....#.....#.#...#.....#...#.#.#...#.#.#.#...#..n#...#",
             "#.###.#.#.#.#########.###.#.#.#.#####J#.###.###.#.#####.#.###.###.#.#######.#.###",
             "#.#...#...#...#...#...#.#...#.#.....#.#.#...#.#.#.....#.#...#...#.#.........#.#.#",
             "###.#########.#.###F###.#####.#######.#.#.###.#.#####T#.###.###.#.#.#.#####.#.#.#",
             "#...#.......#s#...#.........#...#...#...#.#...#.....#.#...#...#.#q#.#.#.....#...#",
             "#.###.#####.#.#.#.#########.###.#.#.###.#.#.#.#####.#####.###.#.#.#.#.#########C#",
             "#..e......#...#.#.............#...#.....#...#.....#...........#...#.#...........#",
             "#################################################################################"]

start_pos = {}
goal_pos = {}
road_cells = []
keys = []
doors = []
lower_letters = 'abcdefghijklmnopqrstuvwxyz'
upper_letters = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# Parse maze, non-wall cells are considered roads.
for r in range(len(char_maze[:])):
    for c in range(len(char_maze[0])):
        char = char_maze[r][c]
        if not char == '#': 
            road_cells.append((r,c))
        if char == '@':
            start_pos[char] = (r,c)
        if char in lower_letters:
            keys.append(char)
            start_pos[char] = (r,c)
        if char in upper_letters:
            doors.append(char)


depends = {}
steps_from_to = {}
bonus_keys_from_to = {}

for source, destination in permutations(start_pos.keys(),2):
    print(f"\n{source=}, \t{destination=}", end='', flush=True)
    # Explore maze from, to
    frontier = [start_pos[source]]
    visited = {} # cell : previous cell
    #visited[start_pos[source]] = start_pos[source]
    # Backtracking algorithm
    while frontier:
        f = frontier.pop(0)
        up = (f[0]-1,f[1])
        down = (f[0]+1,f[1])
        left = (f[0],f[1]-1)
        right = (f[0],f[1]+1)
        if (up    not in visited) and (up    in road_cells): 
            visited[up]    = f
            frontier.append(up)    # Add key, and from where it came from
        if (down  not in visited) and (down  in road_cells): 
            visited[down]  = f
            frontier.append(down)  # Add key, and from where it came from
        if (left  not in visited) and (left  in road_cells): 
            visited[left]  = f
            frontier.append(left)  # Add key, and from where it came from
        if (right not in visited) and (right in road_cells): 
            visited[right] = f
            frontier.append(right) # Add key, and from where it came from
    # Backtrack, and record dependencies
    pos = start_pos[destination]
    steps = 0
    bonus_keys_from_to[source,destination] = set()
    if source=='@':
        depends[destination] = set()
    if pos not in visited:
        steps = -1
    else:
        while pos != start_pos[source]:
            pos = visited[pos]
            # Add dependencies if we crossed a door
            C = char_maze[pos[0]][pos[1]]
            if C in doors:
                if source=='@':
                    depends[destination].add(C.lower())
            # Add "keys captured along they way kind of thing"
            if C in keys and C not in (source):
                bonus_keys_from_to[source,destination].add(C)
                # TRY TODO CHECK: to reduce tree, only allow first visible key to be reached (not the ones behind, even if there are no doors)
                if source=='@':
                    depends[destination].add(C)
            steps += 1
    steps_from_to[source,destination] = steps
    print(f", \t{steps=}",end='',flush=True)
    print(f", \t{bonus_keys_from_to[source,destination]=}",end='',flush=True)
    if source=='@':
        print(f", \t{depends[destination]=}",end='',flush=True)
print('\n')
print(steps_from_to)
print(depends)
# Out:
# ion]={'w', 'e', 'u'}
# source='s', 	destination='f', 	steps=472, 	bonus_keys_from_to[source,destination]={'w', 'e', 'u', 'a', 'j'}
# source='s', 	destination='a', 	steps=458, 	bonus_keys_from_to[source,destination]={'w', 'e', 'j', 'u'}
# source='s', 	destination='j', 	steps=446, 	bonus_keys_from_to[source,destination]={'w', 'e', 'u'}
# source='s', 	destination='v', 	steps=570, 	bonus_keys_from_to[source,destination]={'w', 'e', 'c', 'u'}
# source='s', 	destination='t', 	steps=486, 	bonus_keys_from_to[source,destination]={'w', 'e', 'u'}
# source='s', 	destination='i', 	steps=392, 	bonus_keys_from_to[source,destination]={'w', 'e', 'u'}
# source='s', 	destination='x', 	steps=542, 	bonus_keys_from_to[source,destination]={'w', 'e', 'u'}
# source='s', 	destination='@', 	steps=364, 	bonus_keys_from_to[source,destination]={'w', 'e', 'u'}
# source='s', 	destination='p', 	steps=374, 	bonus_keys_from_to[source,destination]={'w', 'e', 'u'}
# source='s', 	destination='r', 	steps=424, 	bonus_keys_from_to[source,destination]={'w', 'e', 'u'}
# source='s', 	destination='z', 	steps=288, 	bonus_keys_from_to[source,destination]={'w', 'e', 'u'}
# source='s', 	destination='o', 	steps=618, 	bonus_keys_from_to[source,destination]={'w', 'e', 'q', 'p', 'u', 'g'}
# source='s', 	destination='b', 	steps=744, 	bonus_keys_from_to[source,destination]={'o', 'w', 'e', 'l', 'q', 'p', 'u', 'g'}
# source='s', 	destination='y', 	steps=332, 	bonus_keys_from_to[source,destination]={'w', 'e', 'u'}
# source='s', 	destination='l', 	steps=632, 	bonus_keys_from_to[source,destination]={'o', 'w', 'e', 'q', 'p', 'u', 'g'}
# source='s', 	destination='g', 	steps=604, 	bonus_keys_from_to[source,destination]={'w', 'e', 'q', 'p', 'u'}
# source='s', 	destination='h', 	steps=50, 	bonus_keys_from_to[source,destination]={'d'}
# source='s', 	destination='w', 	steps=32, 	bonus_keys_from_to[source,destination]={'e'}
# source='s', 	destination='d', 	steps=32, 	bonus_keys_from_to[source,destination]=set()
# source='s', 	destination='m', 	steps=648, 	bonus_keys_from_to[source,destination]={'o', 'w', 'e', 'l', 'q', 'p', 'u', 'g'}
# source='s', 	destination='k', 	steps=100, 	bonus_keys_from_to[source,destination]={'w', 'e', 'u'}
# source='s', 	destination='u', 	steps=44, 	bonus_keys_from_to[source,destination]={'w', 'e'}
# source='s', 	destination='n', 	steps=586, 	bonus_keys_from_to[source,destination]={'w', 'e', 'q', 'p', 'u'}
# source='s', 	destination='q', 	steps=508, 	bonus_keys_from_to[source,destination]={'p', 'w', 'e', 'u'}
# source='s', 	destination='e', 	steps=16, 	bonus_keys_from_to[source,destination]=set()
# source='q', 	destination='c', 	steps=336, 	bonus_keys_from_to[source,destination]={'p'}
# source='q', 	destination='f', 	steps=252, 	bonus_keys_from_to[source,destination]={'a', 'j', 'p'}
# source='q', 	destination='a', 	steps=238, 	bonus_keys_from_to[source,destination]={'p', 'j'}
# source='q', 	destination='j', 	steps=226, 	bonus_keys_from_to[source,destination]={'p'}
# source='q', 	destination='v', 	steps=354, 	bonus_keys_from_to[source,destination]={'p', 'c'}
# source='q', 	destination='t', 	steps=270, 	bonus_keys_from_to[source,destination]={'p'}
# source='q', 	destination='i', 	steps=172, 	bonus_keys_from_to[source,destination]={'p'}
# source='q', 	destination='x', 	steps=322, 	bonus_keys_from_to[source,destination]={'p'}
# source='q', 	destination='@', 	steps=146, 	bonus_keys_from_to[source,destination]={'p'}
# source='q', 	destination='p', 	steps=134, 	bonus_keys_from_to[source,destination]=set()
# source='q', 	destination='r', 	steps=188, 	bonus_keys_from_to[source,destination]={'p'}
# source='q', 	destination='z', 	steps=304, 	bonus_keys_from_to[source,destination]={'p'}
# source='q', 	destination='o', 	steps=110, 	bonus_keys_from_to[source,destination]={'g'}
# source='q', 	destination='b', 	steps=236, 	bonus_keys_from_to[source,destination]={'o', 'l', 'g'}
# source='q', 	destination='y', 	steps=192, 	bonus_keys_from_to[source,destination]={'p'}
# source='q', 	destination='l', 	steps=124, 	bonus_keys_from_to[source,destination]={'o', 'g'}
# source='q', 	destination='g', 	steps=96, 	bonus_keys_from_to[source,destination]=set()
# source='q', 	destination='h', 	steps=558, 	bonus_keys_from_to[source,destination]={'w', 'e', 's', 'p', 'd', 'u'}
# source='q', 	destination='w', 	steps=476, 	bonus_keys_from_to[source,destination]={'p', 'u'}
# source='q', 	destination='d', 	steps=540, 	bonus_keys_from_to[source,destination]={'w', 'e', 's', 'p', 'u'}
# source='q', 	destination='m', 	steps=140, 	bonus_keys_from_to[source,destination]={'o', 'l', 'g'}
# source='q', 	destination='k', 	steps=444, 	bonus_keys_from_to[source,destination]={'p'}
# source='q', 	destination='u', 	steps=464, 	bonus_keys_from_to[source,destination]={'p'}
# source='q', 	destination='n', 	steps=78, 	bonus_keys_from_to[source,destination]=set()
# source='q', 	destination='s', 	steps=508, 	bonus_keys_from_to[source,destination]={'p', 'w', 'e', 'u'}
# source='q', 	destination='e', 	steps=492, 	bonus_keys_from_to[source,destination]={'p', 'w', 'u'}
# source='e', 	destination='c', 	steps=536, 	bonus_keys_from_to[source,destination]={'w', 'u'}
# source='e', 	destination='f', 	steps=456, 	bonus_keys_from_to[source,destination]={'a', 'w', 'j', 'u'}
# source='e', 	destination='a', 	steps=442, 	bonus_keys_from_to[source,destination]={'w', 'j', 'u'}
# source='e', 	destination='j', 	steps=430, 	bonus_keys_from_to[source,destination]={'w', 'u'}
# source='e', 	destination='v', 	steps=554, 	bonus_keys_from_to[source,destination]={'w', 'c', 'u'}
# source='e', 	destination='t', 	steps=470, 	bonus_keys_from_to[source,destination]={'w', 'u'}
# source='e', 	destination='i', 	steps=376, 	bonus_keys_from_to[source,destination]={'w', 'u'}
# source='e', 	destination='x', 	steps=526, 	bonus_keys_from_to[source,destination]={'w', 'u'}
# source='e', 	destination='@', 	steps=348, 	bonus_keys_from_to[source,destination]={'w', 'u'}
# source='e', 	destination='p', 	steps=358, 	bonus_keys_from_to[source,destination]={'w', 'u'}
# source='e', 	destination='r', 	steps=408, 	bonus_keys_from_to[source,destination]={'w', 'u'}
# source='e', 	destination='z', 	steps=272, 	bonus_keys_from_to[source,destination]={'w', 'u'}
# source='e', 	destination='o', 	steps=602, 	bonus_keys_from_to[source,destination]={'w', 'q', 'p', 'u', 'g'}
# source='e', 	destination='b', 	steps=728, 	bonus_keys_from_to[source,destination]={'o', 'w', 'l', 'q', 'p', 'u', 'g'}
# source='e', 	destination='y', 	steps=316, 	bonus_keys_from_to[source,destination]={'w', 'u'}
# source='e', 	destination='l', 	steps=616, 	bonus_keys_from_to[source,destination]={'o', 'w', 'q', 'p', 'u', 'g'}
# source='e', 	destination='g', 	steps=588, 	bonus_keys_from_to[source,destination]={'p', 'w', 'q', 'u'}
# source='e', 	destination='h', 	steps=66, 	bonus_keys_from_to[source,destination]={'d', 's'}
# source='e', 	destination='w', 	steps=16, 	bonus_keys_from_to[source,destination]=set()
# source='e', 	destination='d', 	steps=48, 	bonus_keys_from_to[source,destination]={'s'}
# source='e', 	destination='m', 	steps=632, 	bonus_keys_from_to[source,destination]={'o', 'w', 'l', 'q', 'p', 'u', 'g'}
# source='e', 	destination='k', 	steps=84, 	bonus_keys_from_to[source,destination]={'w', 'u'}
# source='e', 	destination='u', 	steps=28, 	bonus_keys_from_to[source,destination]={'w'}
# source='e', 	destination='n', 	steps=570, 	bonus_keys_from_to[source,destination]={'p', 'w', 'q', 'u'}
# source='e', 	destination='s', 	steps=16, 	bonus_keys_from_to[source,destination]=set()
# source='e', 	destination='q', 	steps=492, 	bonus_keys_from_to[source,destination]={'p', 'w', 'u'}
#
# {('c', 'f'): 296, ('c', 'a'): 282, ('c', 'j'): 270, ('c', 'v'): 18, ('c', 't'): 70, ('c', 'i'): 216, ('c', 'x'): 366, ('c', '@'): 190, ('c', 'p'): 202, ('c', 'r'): 252, ('c', 'z'): 348, ('c', 'o'): 446, ('c', 'b'): 572, ('c', 'y'): 236, ('c', 'l'): 460, ('c', 'g'): 432, ('c', 'h'): 602, ('c', 'w'): 520, ('c', 'd'): 584, ('c', 'm'): 476, ('c', 'k'): 488, ('c', 'u'): 508, ('c', 'n'): 414, ('c', 's'): 552, ('c', 'q'): 336, ('c', 'e'): 536, ('f', 'c'): 296, ('f', 'a'): 14, ('f', 'j'): 26, ('f', 'v'): 314, ('f', 't'): 230, ('f', 'i'): 132, ('f', 'x'): 134, ('f', '@'): 108, ('f', 'p'): 118, ('f', 'r'): 168, ('f', 'z'): 268, ('f', 'o'): 362, ('f', 'b'): 488, ('f', 'y'): 156, ('f', 'l'): 376, ('f', 'g'): 348, ('f', 'h'): 522, ('f', 'w'): 440, ('f', 'd'): 504, ('f', 'm'): 392, ('f', 'k'): 408, ('f', 'u'): 428, ('f', 'n'): 330, ('f', 's'): 472, ('f', 'q'): 252, ('f', 'e'): 456, ('a', 'c'): 282, ('a', 'f'): 14, ('a', 'j'): 12, ('a', 'v'): 300, ('a', 't'): 216, ('a', 'i'): 118, ('a', 'x'): 120, ('a', '@'): 94, ('a', 'p'): 104, ('a', 'r'): 154, ('a', 'z'): 254, ('a', 'o'): 348, ('a', 'b'): 474, ('a', 'y'): 142, ('a', 'l'): 362, ('a', 'g'): 334, ('a', 'h'): 508, ('a', 'w'): 426, ('a', 'd'): 490, ('a', 'm'): 378, ('a', 'k'): 394, ('a', 'u'): 414, ('a', 'n'): 316, ('a', 's'): 458, ('a', 'q'): 238, ('a', 'e'): 442, ('j', 'c'): 270, ('j', 'f'): 26, ('j', 'a'): 12, ('j', 'v'): 288, ('j', 't'): 204, ('j', 'i'): 106, ('j', 'x'): 108, ('j', '@'): 82, ('j', 'p'): 92, ('j', 'r'): 142, ('j', 'z'): 242, ('j', 'o'): 336, ('j', 'b'): 462, ('j', 'y'): 130, ('j', 'l'): 350, ('j', 'g'): 322, ('j', 'h'): 496, ('j', 'w'): 414, ('j', 'd'): 478, ('j', 'm'): 366, ('j', 'k'): 382, ('j', 'u'): 402, ('j', 'n'): 304, ('j', 's'): 446, ('j', 'q'): 226, ('j', 'e'): 430, ('v', 'c'): 18, ('v', 'f'): 314, ('v', 'a'): 300, ('v', 'j'): 288, ('v', 't'): 88, ('v', 'i'): 234, ('v', 'x'): 384, ('v', '@'): 208, ('v', 'p'): 220, ('v', 'r'): 270, ('v', 'z'): 366, ('v', 'o'): 464, ('v', 'b'): 590, ('v', 'y'): 254, ('v', 'l'): 478, ('v', 'g'): 450, ('v', 'h'): 620, ('v', 'w'): 538, ('v', 'd'): 602, ('v', 'm'): 494, ('v', 'k'): 506, ('v', 'u'): 526, ('v', 'n'): 432, ('v', 's'): 570, ('v', 'q'): 354, ('v', 'e'): 554, ('t', 'c'): 70, ('t', 'f'): 230, ('t', 'a'): 216, ('t', 'j'): 204, ('t', 'v'): 88, ('t', 'i'): 150, ('t', 'x'): 300, ('t', '@'): 124, ('t', 'p'): 136, ('t', 'r'): 186, ('t', 'z'): 282, ('t', 'o'): 380, ('t', 'b'): 506, ('t', 'y'): 170, ('t', 'l'): 394, ('t', 'g'): 366, ('t', 'h'): 536, ('t', 'w'): 454, ('t', 'd'): 518, ('t', 'm'): 410, ('t', 'k'): 422, ('t', 'u'): 442, ('t', 'n'): 348, ('t', 's'): 486, ('t', 'q'): 270, ('t', 'e'): 470, ('i', 'c'): 216, ('i', 'f'): 132, ('i', 'a'): 118, ('i', 'j'): 106, ('i', 'v'): 234, ('i', 't'): 150, ('i', 'x'): 202, ('i', '@'): 28, ('i', 'p'): 38, ('i', 'r'): 88, ('i', 'z'): 188, ('i', 'o'): 282, ('i', 'b'): 408, ('i', 'y'): 76, ('i', 'l'): 296, ('i', 'g'): 268, ('i', 'h'): 442, ('i', 'w'): 360, ('i', 'd'): 424, ('i', 'm'): 312, ('i', 'k'): 328, ('i', 'u'): 348, ('i', 'n'): 250, ('i', 's'): 392, ('i', 'q'): 172, ('i', 'e'): 376, ('x', 'c'): 366, ('x', 'f'): 134, ('x', 'a'): 120, ('x', 'j'): 108, ('x', 'v'): 384, ('x', 't'): 300, ('x', 'i'): 202, ('x', '@'): 178, ('x', 'p'): 188, ('x', 'r'): 238, ('x', 'z'): 338, ('x', 'o'): 432, ('x', 'b'): 558, ('x', 'y'): 226, ('x', 'l'): 446, ('x', 'g'): 418, ('x', 'h'): 592, ('x', 'w'): 510, ('x', 'd'): 574, ('x', 'm'): 462, ('x', 'k'): 478, ('x', 'u'): 498, ('x', 'n'): 400, ('x', 's'): 542, ('x', 'q'): 322, ('x', 'e'): 526, ('@', 'c'): 190, ('@', 'f'): 108, ('@', 'a'): 94, ('@', 'j'): 82, ('@', 'v'): 208, ('@', 't'): 124, ('@', 'i'): 28, ('@', 'x'): 178, ('@', 'p'): 12, ('@', 'r'): 62, ('@', 'z'): 160, ('@', 'o'): 256, ('@', 'b'): 382, ('@', 'y'): 48, ('@', 'l'): 270, ('@', 'g'): 242, ('@', 'h'): 414, ('@', 'w'): 332, ('@', 'd'): 396, ('@', 'm'): 286, ('@', 'k'): 300, ('@', 'u'): 320, ('@', 'n'): 224, ('@', 's'): 364, ('@', 'q'): 146, ('@', 'e'): 348, ('p', 'c'): 202, ('p', 'f'): 118, ('p', 'a'):  ...
# {'c': {'q', 'x'}, 'f': {'r', 'y', 'p', 'a', 'j'}, 'a': {'p', 'j', 'r', 'y'}, 'j': {'p', 'y', 'r'}, 'v': {'q', 'c', 'x'}, 't': set(), 'i': set(), 'x': {'p', 'z', 'y', 'r'}, 'p': set(), 'r': set(), 'z': {'i', 'j'}, 'o': {'p', 'q', 'g'}, 'b': {'w', 'o', 'e', 'l', 'q', 'p', 'g'}, 'y': set(), 'l': {'p', 'o', 'q', 'g'}, 'g': {'p', 'q'}, 'h': {'w', 'e', 's', 'l', 'i', 'j', 'd', 'u', 'g', 'b'}, 'w': {'i', 'l', 'u', 'g', 'j'}, 'd': {'w', 'e', 's', 'l', 'i', 'j', 'u', 'g', 'b'}, 'm': {'o', 'l', 'q', 'p', 'g'}, 'k': {'m', 'i', 'j', 'g'}, 'u': {'i', 'j', 'l', 'g'}, 'n': {'p', 'q', 'c'}, 's': {'w', 'e', 'i', 'l', 'u', 'g', 'j'}, 'q': {'p'}, 'e': {'w', 'i', 'l', 'u', 'g', 'j'}}

# %%
# Iterative solution to get all keys in the least amount of steps
stateNT = namedtuple('state','owned_keys reachable_keys steps current_position')
owned_keys = set()
state = stateNT( owned_keys = owned_keys, 
                 reachable_keys = get_reachable_keys(owned_keys, depends), 
                 steps = 0,
                 current_position = '@')

Q = deque()
Q.append(state)
solutions = []
sets_list = []
steps_list = [] # Min steps associated to get that set of keys (kill early combinations that took too many steps)
heads_list = [] # Position associated with a set of keys
# BFS, try to get all keys!
iterations = 0
min_steps = 10000
n_solutions = 0
keys_target = len(keys)
max_got_keys = 0
while Q:
    iterations+=1
    S = Q.popleft()
    if iterations%10000==0:
        print(f'{iterations=}, {n_solutions=}, {min_steps=}, {max_got_keys=}/{keys_target}, {Q.')
        #print(S)
    assert(isinstance(S.reachable_keys, set))
    assert(isinstance(S.owned_keys, set))
    for k in S.reachable_keys:
        steps = S.steps
        steps += steps_from_to[S.current_position, k]
        #print(f"Go from {S.current_position} to {k}")
        owned_keys = deepcopy(S.owned_keys)
        # This does not take into account the keys that may be collected on the way to another key
        # For a first solution it's ok, because  when going from a to c in a-b-c
        # the a-c-b solution (fake) will be longer than a-b-c and discarded later on
        # Problem is that it adds many more iterations. Should consider to add a "keys captured
        # along the way to destination" kind of thing
        owned_keys.add(k)
        owned_keys.union(bonus_keys_from_to[S.current_position, k])
        current_position = k
        reachable_keys = get_reachable_keys(owned_keys, depends)
        new_state = stateNT(owned_keys = owned_keys, 
                            reachable_keys = reachable_keys, 
                            steps = steps, 
                            current_position = current_position)
        #print(new_state)
        continue_branch = True
        if owned_keys not in sets_list:
            sets_list.append(owned_keys)
            steps_list.append(steps)
            heads_list.append(current_position)
            max_got_keys = max(max_got_keys, len(owned_keys))
        else:
            iset = sets_list.index(owned_keys)
            if steps >= steps_list[iset] and current_position==heads_list[iset]:
                # We already got at this point and we're not doing better
                continue_branch = False
            else:
                steps_list[iset] = steps
                heads_list[iset] = current_position
        if steps > 3864: # We know we can do better than this
            continue_branch = False
        if not new_state.reachable_keys:
            # There are no more reachable keys! We may have them all :)
            #print("ONE SOLUTION WAS FOUND!!!")
            #print(new_state)
            #solutions.append(new_state)
            min_steps = min(min_steps, steps)
            n_solutions += 1
        else:
            if continue_branch:
                if Q and (steps <= Q[0].steps): # Prioritise shortest solutions
                    Q.appendleft(deepcopy(new_state))
                else:
                    Q.append(deepcopy(new_state))

# min_steps = 1e10
# for s in solutions:
#     if s.steps<min_steps:
#         min_steps = s.steps

print(f"Solution part 1 is: {min_steps=} among {n_solutions=} with a total of {iterations=}")
# Out:
# s=26/26
# iterations=4380000, n_solutions=437, min_steps=3864, max_got_keys=26/26
# iterations=4390000, n_solutions=437, min_steps=3864, max_got_keys=26/26
# iterations=4400000, n_solutions=442, min_steps=3864, max_got_keys=26/26
# iterations=4410000, n_solutions=449, min_steps=3864, max_got_keys=26/26
# iterations=4420000, n_solutions=465, min_steps=3864, max_got_keys=26/26
# iterations=4430000, n_solutions=465, min_steps=3864, max_got_keys=26/26
# iterations=4440000, n_solutions=465, min_steps=3864, max_got_keys=26/26
# iterations=4450000, n_solutions=468, min_steps=3864, max_got_keys=26/26
# iterations=4460000, n_solutions=481, min_steps=3864, max_got_keys=26/26
# iterations=4470000, n_solutions=481, min_steps=3864, max_got_keys=26/26
# iterations=4480000, n_solutions=481, min_steps=3864, max_got_keys=26/26
# iterations=4490000, n_solutions=483, min_steps=3864, max_got_keys=26/26
# iterations=4500000, n_solutions=494, min_steps=3864, max_got_keys=26/26
# iterations=4510000, n_solutions=494, min_steps=3864, max_got_keys=26/26
# iterations=4520000, n_solutions=494, min_steps=3864, max_got_keys=26/26
# iterations=4530000, n_solutions=494, min_steps=3864, max_got_keys=26/26
# iterations=4540000, n_solutions=497, min_steps=3864, max_got_keys=26/26
# iterations=4550000, n_solutions=497, min_steps=3864, max_got_keys=26/26
# iterations=4560000, n_solutions=497, min_steps=3864, max_got_keys=26/26
# iterations=4570000, n_solutions=499, min_steps=3864, max_got_keys=26/26
# iterations=4580000, n_solutions=502, min_steps=3864, max_got_keys=26/26
# iterations=4590000, n_solutions=502, min_steps=3864, max_got_keys=26/26
# iterations=4600000, n_solutions=503, min_steps=3864, max_got_keys=26/26
# iterations=4610000, n_solutions=513, min_steps=3864, max_got_keys=26/26
# iterations=4620000, n_solutions=519, min_steps=3864, max_got_keys=26/26
# iterations=4630000, n_solutions=520, min_steps=3864, max_got_keys=26/26
# iterations=4640000, n_solutions=526, min_steps=3864, max_got_keys=26/26
# iterations=4650000, n_solutions=536, min_steps=3864, max_got_keys=26/26
# iterations=4660000, n_solutions=565, min_steps=3864, max_got_keys=26/26
# iterations=4670000, n_solutions=565, min_steps=3864, max_got_keys=26/26
# iterations=4680000, n_solutions=565, min_steps=3864, max_got_keys=26/26
# iterations=4690000, n_solutions=570, min_steps=3864, max_got_keys=26/26
# iterations=4700000, n_solutions=575, min_steps=3864, max_got_keys=26/26
# iterations=4710000, n_solutions=609, min_steps=3864, max_got_keys=26/26
# iterations=4720000, n_solutions=619, min_steps=3864, max_got_keys=26/26
# iterations=4730000, n_solutions=631, min_steps=3864, max_got_keys=26/26
# iterations=4740000, n_solutions=642, min_steps=3864, max_got_keys=26/26
# iterations=4750000, n_solutions=642, min_steps=3864, max_got_keys=26/26
# iterations=4760000, n_solutions=642, min_steps=3864, max_got_keys=26/26
# iterations=4770000, n_solutions=648, min_steps=3864, max_got_keys=26/26
# iterations=4780000, n_solutions=654, min_steps=3864, max_got_keys=26/26
# iterations=4790000, n_solutions=658, min_steps=3864, max_got_keys=26/26
# iterations=4800000, n_solutions=667, min_steps=3864, max_got_keys=26/26
# iterations=4810000, n_solutions=667, min_steps=3864, max_got_keys=26/26
# iterations=4820000, n_solutions=668, min_steps=3864, max_got_keys=26/26
# iterations=4830000, n_solutions=668, min_steps=3864, max_got_keys=26/26
# iterations=4840000, n_solutions=668, min_steps=3864, max_got_keys=26/26
# iterations=4850000, n_solutions=677, min_steps=3864, max_got_keys=26/26
# iterations=4860000, n_solutions=677, min_steps=3864, max_got_keys=26/26
# iterations=4870000, n_solutions=689, min_steps=3864, max_got_keys=26/26
# iterations=4880000, n_solutions=690, min_steps=3864, max_got_keys=26/26
# iterations=4890000, n_solutions=709, min_steps=3864, max_got_keys=26/26
# iterations=4900000, n_solutions=715, min_steps=3864, max_got_keys=26/26
# iterations=4910000, n_solutions=716, min_steps=3864, max_got_keys=26/26
# iterations=4920000, n_solutions=718, min_steps=3864, max_got_keys=26/26
# iterations=4930000, n_solutions=718, min_steps=3864, max_got_keys=26/26
# iterations=4940000, n_solutions=746, min_steps=3864, max_got_keys=26/26
# iterations=4950000, n_solutions=746, min_steps=3864, max_got_keys=26/26
# iterations=4960000, n_solutions=750, min_steps=3864, max_got_keys=26/26
# iterations=4970000, n_solutions=753, min_steps=3864, max_got_keys=26/26
# iterations=4980000, n_solutions=753, min_steps=3864, max_got_keys=26/26
# iterations=4990000, n_solutions=753, min_steps=3864, max_got_keys=26/26
# iterations=5000000, n_solutions=753, min_steps=3864, max_got_keys=26/26
# iterations=5010000, n_solutions=753, min_steps=3864, max_got_keys=26/26
# iterations=5020000, n_solutions=764, min_steps=3864, max_got_keys=26/26
# iterations=5030000, n_solutions=765, min_steps=3864, max_got_keys=26/26
# iterations=5040000, n_solutions=767, min_steps=3864, max_got_keys=26/26
# iterations=5050000, n_solutions=770, min_steps=3864, max_got_keys=26/26
# iterations=5060000, n_solutions=770, min_steps=3864, max_got_keys=26/26
# iterations=5070000, n_solutions=776, min_steps=3864, max_got_keys=26/26
# iterations=5080000, n_solutions=776, min_steps=3864, max_got_keys=26/26
# iterations=5090000, n_solutions=776, min_steps=3864, max_got_keys=26/26
# iterations=5100000, n_solutions=776, min_steps=3864, max_got_keys=26/26
# iterations=5110000, n_solutions=783, min_steps=3864, max_got_keys=26/26
# iterations=5120000, n_solutions=783, min_steps=3864, max_got_keys=26/26
# iterations=5130000, n_solutions=809, min_steps=3864, max_got_keys=26/26
# iterations=5140000, n_solutions=809, min_steps=3864, max_got_keys=26/26
# iterations=5150000, n_solutions=814, min_steps=3864, max_got_keys=26/26
# iterations=5160000, n_solutions=822, min_steps=3864, max_got_keys=26/26
# iterations=5170000, n_solutions=823, min_steps=3864, max_got_keys=26/26
# iterations=5180000, n_solutions=824, min_steps=3864, max_got_keys=26/26
# iterations=5190000, n_solutions=833, min_steps=3864, max_got_keys=26/26
# iterations=5200000, n_solutions=847, min_steps=3864, max_got_keys=26/26
# iterations=5210000, n_solutions=858, min_steps=3864, max_got_keys=26/26
# iterations=5220000, n_solutions=871, min_steps=3864, max_got_keys=26/26
# iterations=5230000, n_solutions=871, min_steps=3864, max_got_keys=26/26
# iterations=5240000, n_solutions=871, min_steps=3864, max_got_keys=26/26
# iterations=5250000, n_solutions=871, min_steps=3864, max_got_keys=26/26
# iterations=5260000, n_solutions=871, min_steps=3864, max_got_keys=26/26
# iterations=5270000, n_solutions=871, min_steps=3864, max_got_keys=26/26
# iterations=5280000, n_solutions=882, min_steps=3864, max_got_keys=26/26
# iterations=5290000, n_solutions=883, min_steps=3864, max_got_keys=26/26
# iterations=5300000, n_solutions=884, min_steps=3864, max_got_keys=26/26
# iterations=5310000, n_solutions=888, min_steps=3864, max_got_keys=26/26
# iterations=5320000, n_solutions=920, min_steps=3862, max_got_keys=26/26
# iterations=5330000, n_solutions=920, min_steps=3862, max_got_keys=26/26
# iterations=5340000, n_solutions=940, min_steps=3862, max_got_keys=26/26
# iterations=5350000, n_solutions=940, min_steps=3862, max_got_keys=26/26
# iterations=5360000, n_solutions=945, min_steps=3862, max_got_keys=26/26
# iterations=5370000, n_solutions=957, min_steps=3862, max_got_keys=26/26
# iterations=5380000, n_solutions=971, min_steps=3862, max_got_keys=26/26
# iterations=5390000, n_solutions=996, min_steps=3862, max_got_keys=26/26
# iterations=5400000, n_solutions=996, min_steps=3862, max_got_keys=26/26
# iterations=5410000, n_solutions=1002, min_steps=3862, max_got_keys=26/26
# iterations=5420000, n_solutions=1002, min_steps=3862, max_got_keys=26/26
# iterations=5430000, n_solutions=1002, min_steps=3862, max_got_keys=26/26
# iterations=5440000, n_solutions=1019, min_steps=3862, max_got_keys=26/26
# iterations=5450000, n_solutions=1019, min_steps=3862, max_got_keys=26/26
# iterations=5460000, n_solutions=1025, min_steps=3862, max_got_keys=26/26
# iterations=5470000, n_solutions=1062, min_steps=3862, max_got_keys=26/26
# iterations=5480000, n_solutions=1062, min_steps=3862, max_got_keys=26/26
# iterations=5490000, n_solutions=1062, min_steps=3862, max_got_keys=26/26
# iterations=5500000, n_solutions=1062, min_steps=3862, max_got_keys=26/26
# iterations=5510000, n_solutions=1062, min_steps=3862, max_got_keys=26/26
# iterations=5520000, n_solutions=1062, min_steps=3862, max_got_keys=26/26
# iterations=5530000, n_solutions=1070, min_steps=3862, max_got_keys=26/26
# iterations=5540000, n_solutions=1070, min_steps=3862, max_got_keys=26/26
# iterations=5550000, n_solutions=1070, min_steps=3862, max_got_keys=26/26
# iterations=5560000, n_solutions=1070, min_steps=3862, max_got_keys=26/26
# iterations=5570000, n_solutions=1070, min_steps=3862, max_got_keys=26/26
# iterations=5580000, n_solutions=1070, min_steps=3862, max_got_keys=26/26
# iterations=5590000, n_solutions=1074, min_steps=3862, max_got_keys=26/26
# iterations=5600000, n_solutions=1075, min_steps=3862, max_got_keys=26/26
# iterations=5610000, n_solutions=1084, min_steps=3862, max_got_keys=26/26
# iterations=5620000, n_solutions=1084, min_steps=3862, max_got_keys=26/26
# iterations=5630000, n_solutions=1084, min_steps=3862, max_got_keys=26/26
# iterations=5640000, n_solutions=1084, min_steps=3862, max_got_keys=26/26
# iterations=5650000, n_solutions=1090, min_steps=3862, max_got_keys=26/26
# iterations=5660000, n_solutions=1090, min_steps=3862, max_got_keys=26/26
# iterations=5670000, n_solutions=1100, min_steps=3862, max_got_keys=26/26
# iterations=5680000, n_solutions=1100, min_steps=3862, max_got_keys=26/26
# iterations=5690000, n_solutions=1118, min_steps=3862, max_got_keys=26/26
# iterations=5700000, n_solutions=1119, min_steps=3862, max_got_keys=26/26
# iterations=5710000, n_solutions=1119, min_steps=3862, max_got_keys=26/26
# iterations=5720000, n_solutions=1119, min_steps=3862, max_got_keys=26/26
# iterations=5730000, n_solutions=1134, min_steps=3862, max_got_keys=26/26
# iterations=5740000, n_solutions=1134, min_steps=3862, max_got_keys=26/26
# iterations=5750000, n_solutions=1134, min_steps=3862, max_got_keys=26/26
# iterations=5760000, n_solutions=1134, min_steps=3862, max_got_keys=26/26
# iterations=5770000, n_solutions=1134, min_steps=3862, max_got_keys=26/26
# iterations=5780000, n_solutions=1134, min_steps=3862, max_got_keys=26/26
# iterations=5790000, n_solutions=1134, min_steps=3862, max_got_keys=26/26
# iterations=5800000, n_solutions=1134, min_steps=3862, max_got_keys=26/26
# iterations=5810000, n_solutions=1141, min_steps=3862, max_got_keys=26/26
# iterations=5820000, n_solutions=1148, min_steps=3862, max_got_keys=26/26
# iterations=5830000, n_solutions=1172, min_steps=3862, max_got_keys=26/26
# iterations=5840000, n_solutions=1172, min_steps=3862, max_got_keys=26/26
# iterations=5850000, n_solutions=1172, min_steps=3862, max_got_keys=26/26
# iterations=5860000, n_solutions=1172, min_steps=3862, max_got_keys=26/26
# iterations=5870000, n_solutions=1172, min_steps=3862, max_got_keys=26/26
# iterations=5880000, n_solutions=1172, min_steps=3862, max_got_keys=26/26
# iterations=5890000, n_solutions=1172, min_steps=3862, max_got_keys=26/26
# iterations=5900000, n_solutions=1172, min_steps=3862, max_got_keys=26/26
# iterations=5910000, n_solutions=1182, min_steps=3862, max_got_keys=26/26
# iterations=5920000, n_solutions=1187, min_steps=3862, max_got_keys=26/26
# iterations=5930000, n_solutions=1219, min_steps=3862, max_got_keys=26/26
# iterations=5940000, n_solutions=1219, min_steps=3862, max_got_keys=26/26
# iterations=5950000, n_solutions=1219, min_steps=3862, max_got_keys=26/26
# iterations=5960000, n_solutions=1219, min_steps=3862, max_got_keys=26/26
# iterations=5970000, n_solutions=1237, min_steps=3862, max_got_keys=26/26
# iterations=5980000, n_solutions=1245, min_steps=3862, max_got_keys=26/26
# iterations=5990000, n_solutions=1290, min_steps=3862, max_got_keys=26/26
# iterations=6000000, n_solutions=1290, min_steps=3862, max_got_keys=26/26
# iterations=6010000, n_solutions=1290, min_steps=3862, max_got_keys=26/26
# iterations=6020000, n_solutions=1303, min_steps=3862, max_got_keys=26/26
# iterations=6030000, n_solutions=1319, min_steps=3862, max_got_keys=26/26
# iterations=6040000, n_solutions=1319, min_steps=3862, max_got_keys=26/26
# iterations=6050000, n_solutions=1335, min_steps=3862, max_got_keys=26/26
# iterations=6060000, n_solutions=1354, min_steps=3862, max_got_keys=26/26
# iterations=6070000, n_solutions=1354, min_steps=3862, max_got_keys=26/26
# iterations=6080000, n_solutions=1371, min_steps=3862, max_got_keys=26/26
# iterations=6090000, n_solutions=1371, min_steps=3862, max_got_keys=26/26
# iterations=6100000, n_solutions=1373, min_steps=3862, max_got_keys=26/26
# iterations=6110000, n_solutions=1387, min_steps=3862, max_got_keys=26/26
# iterations=6120000, n_solutions=1407, min_steps=3862, max_got_keys=26/26
# iterations=6130000, n_solutions=1421, min_steps=3862, max_got_keys=26/26
# iterations=6140000, n_solutions=1448, min_steps=3862, max_got_keys=26/26
# iterations=6150000, n_solutions=1488, min_steps=3862, max_got_keys=26/26
# iterations=6160000, n_solutions=1523, min_steps=3862, max_got_keys=26/26
# iterations=6170000, n_solutions=1553, min_steps=3862, max_got_keys=26/26
# iterations=6180000, n_solutions=1553, min_steps=3862, max_got_keys=26/26
# iterations=6190000, n_solutions=1571, min_steps=3862, max_got_keys=26/26
# iterations=6200000, n_solutions=1596, min_steps=3862, max_got_keys=26/26
# iterations=6210000, n_solutions=1598, min_steps=3862, max_got_keys=26/26
# iterations=6220000, n_solutions=1598, min_steps=3862, max_got_keys=26/26
# iterations=6230000, n_solutions=1604, min_steps=3862, max_got_keys=26/26
# iterations=6240000, n_solutions=1616, min_steps=3862, max_got_keys=26/26
# iterations=6250000, n_solutions=1640, min_steps=3862, max_got_keys=26/26
# iterations=6260000, n_solutions=1674, min_steps=3862, max_got_keys=26/26
# iterations=6270000, n_solutions=1687, min_steps=3862, max_got_keys=26/26
# iterations=6280000, n_solutions=1716, min_steps=3862, max_got_keys=26/26
# iterations=6290000, n_solutions=1721, min_steps=3862, max_got_keys=26/26
# iterations=6300000, n_solutions=1721, min_steps=3862, max_got_keys=26/26
# iterations=6310000, n_solutions=1729, min_steps=3862, max_got_keys=26/26
# iterations=6320000, n_solutions=1729, min_steps=3862, max_got_keys=26/26
# iterations=6330000, n_solutions=1756, min_steps=3862, max_got_keys=26/26
# iterations=6340000, n_solutions=1756, min_steps=3862, max_got_keys=26/26
# iterations=6350000, n_solutions=1767, min_steps=3862, max_got_keys=26/26
# iterations=6360000, n_solutions=1768, min_steps=3862, max_got_keys=26/26
# iterations=6370000, n_solutions=1780, min_steps=3862, max_got_keys=26/26
# iterations=6380000, n_solutions=1784, min_steps=3862, max_got_keys=26/26
# iterations=6390000, n_solutions=1790, min_steps=3862, max_got_keys=26/26
# iterations=6400000, n_solutions=1796, min_steps=3862, max_got_keys=26/26
# iterations=6410000, n_solutions=1816, min_steps=3862, max_got_keys=26/26
# iterations=6420000, n_solutions=1816, min_steps=3862, max_got_keys=26/26
# iterations=6430000, n_solutions=1845, min_steps=3862, max_got_keys=26/26
# iterations=6440000, n_solutions=1861, min_steps=3862, max_got_keys=26/26
# iterations=6450000, n_solutions=1874, min_steps=3862, max_got_keys=26/26
# iterations=6460000, n_solutions=1874, min_steps=3862, max_got_keys=26/26
# iterations=6470000, n_solutions=1874, min_steps=3862, max_got_keys=26/26
# iterations=6480000, n_solutions=1888, min_steps=3862, max_got_keys=26/26
# iterations=6490000, n_solutions=1908, min_steps=3862, max_got_keys=26/26
# iterations=6500000, n_solutions=1957, min_steps=3862, max_got_keys=26/26
# iterations=6510000, n_solutions=1979, min_steps=3862, max_got_keys=26/26
# iterations=6520000, n_solutions=2008, min_steps=3862, max_got_keys=26/26
# iterations=6530000, n_solutions=2056, min_steps=3862, max_got_keys=26/26
# iterations=6540000, n_solutions=2078, min_steps=3862, max_got_keys=26/26
# iterations=6550000, n_solutions=2096, min_steps=3862, max_got_keys=26/26
# iterations=6560000, n_solutions=2138, min_steps=3862, max_got_keys=26/26
# iterations=6570000, n_solutions=2138, min_steps=3862, max_got_keys=26/26
# iterations=6580000, n_solutions=2138, min_steps=3862, max_got_keys=26/26
# iterations=6590000, n_solutions=2140, min_steps=3862, max_got_keys=26/26
# iterations=6600000, n_solutions=2140, min_steps=3862, max_got_keys=26/26
# iterations=6610000, n_solutions=2140, min_steps=3862, max_got_keys=26/26
# iterations=6620000, n_solutions=2159, min_steps=3862, max_got_keys=26/26
# iterations=6630000, n_solutions=2166, min_steps=3862, max_got_keys=26/26
# iterations=6640000, n_solutions=2187, min_steps=3862, max_got_keys=26/26
# iterations=6650000, n_solutions=2187, min_steps=3862, max_got_keys=26/26
# iterations=6660000, n_solutions=2198, min_steps=3862, max_got_keys=26/26
# iterations=6670000, n_solutions=2198, min_steps=3862, max_got_keys=26/26
# iterations=6680000, n_solutions=2223, min_steps=3862, max_got_keys=26/26
# iterations=6690000, n_solutions=2236, min_steps=3862, max_got_keys=26/26
# iterations=6700000, n_solutions=2240, min_steps=3862, max_got_keys=26/26
# iterations=6710000, n_solutions=2249, min_steps=3862, max_got_keys=26/26
# iterations=6720000, n_solutions=2249, min_steps=3862, max_got_keys=26/26
# iterations=6730000, n_solutions=2249, min_steps=3862, max_got_keys=26/26
# iterations=6740000, n_solutions=2249, min_steps=3862, max_got_keys=26/26
# iterations=6750000, n_solutions=2261, min_steps=3862, max_got_keys=26/26
# iterations=6760000, n_solutions=2298, min_steps=3862, max_got_keys=26/26
# iterations=6770000, n_solutions=2298, min_steps=3862, max_got_keys=26/26
# iterations=6780000, n_solutions=2298, min_steps=3862, max_got_keys=26/26
# iterations=6790000, n_solutions=2303, min_steps=3862, max_got_keys=26/26
# iterations=6800000, n_solutions=2323, min_steps=3862, max_got_keys=26/26
# iterations=6810000, n_solutions=2349, min_steps=3862, max_got_keys=26/26
# iterations=6820000, n_solutions=2373, min_steps=3862, max_got_keys=26/26
# iterations=6830000, n_solutions=2420, min_steps=3862, max_got_keys=26/26
# iterations=6840000, n_solutions=2464, min_steps=3862, max_got_keys=26/26
# iterations=6850000, n_solutions=2492, min_steps=3862, max_got_keys=26/26
# iterations=6860000, n_solutions=2538, min_steps=3862, max_got_keys=26/26
# iterations=6870000, n_solutions=2615, min_steps=3862, max_got_keys=26/26
# iterations=6880000, n_solutions=2659, min_steps=3862, max_got_keys=26/26
# iterations=6890000, n_solutions=2673, min_steps=3862, max_got_keys=26/26
# iterations=6900000, n_solutions=2750, min_steps=3862, max_got_keys=26/26
# iterations=6910000, n_solutions=2752, min_steps=3862, max_got_keys=26/26
# iterations=6920000, n_solutions=2795, min_steps=3862, max_got_keys=26/26
# iterations=6930000, n_solutions=2795, min_steps=3862, max_got_keys=26/26
# iterations=6940000, n_solutions=2820, min_steps=3862, max_got_keys=26/26
# iterations=6950000, n_solutions=2848, min_steps=3862, max_got_keys=26/26
# iterations=6960000, n_solutions=2888, min_steps=3862, max_got_keys=26/26
# iterations=6970000, n_solutions=2938, min_steps=3862, max_got_keys=26/26
# iterations=6980000, n_solutions=2940, min_steps=3862, max_got_keys=26/26
# iterations=6990000, n_solutions=3039, min_steps=3862, max_got_keys=26/26
# iterations=7000000, n_solutions=3103, min_steps=3862, max_got_keys=26/26
# iterations=7010000, n_solutions=3111, min_steps=3862, max_got_keys=26/26
# iterations=7020000, n_solutions=3158, min_steps=3862, max_got_keys=26/26
# iterations=7030000, n_solutions=3171, min_steps=3862, max_got_keys=26/26
# iterations=7040000, n_solutions=3214, min_steps=3862, max_got_keys=26/26
# iterations=7050000, n_solutions=3214, min_steps=3862, max_got_keys=26/26
# iterations=7060000, n_solutions=3239, min_steps=3862, max_got_keys=26/26
# iterations=7070000, n_solutions=3267, min_steps=3862, max_got_keys=26/26
# iterations=7080000, n_solutions=3390, min_steps=3862, max_got_keys=26/26
# iterations=7090000, n_solutions=3428, min_steps=3862, max_got_keys=26/26
# iterations=7100000, n_solutions=3533, min_steps=3862, max_got_keys=26/26
# iterations=7110000, n_solutions=3630, min_steps=3862, max_got_keys=26/26
# Solution part 1 is: min_steps=3862 among n_solutions=3708 with a total of iterations=7119090
