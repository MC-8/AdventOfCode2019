# %%
from itertools import permutations
from collections import namedtuple, deque
from copy import deepcopy

def get_reachable_keys(owned_keys, key_dependencies):
    reachable_keys = set()
    for k in key_dependencies.keys():
        if key_dependencies[k].issubset(owned_keys):
            reachable_keys.add(k)
    # Purge owned keys from reachable keys
    #if reachable_keys.intersection(owned_keys):
    for k in reachable_keys.intersection(owned_keys):
        reachable_keys.remove(k)
    return reachable_keys

def get_visible_keys(owned_keys, key_dependencies):
    visible_keys = set()
    for k in key_dependencies.keys():
        if key_dependencies[k].issubset(owned_keys):
            visible_keys.add(k)
    # Purge owned keys from visible keys
    #if visible_keys.intersection(owned_keys):
    for k in visible_keys.intersection(owned_keys):
        visible_keys.remove(k)
    return visible_keys

char_maze = ["#########",
             "#b.A.@.a#",
             "#########"]

char_maze = ["########################",
             "#f.D.E.e.C.b.A.@.a.B.c.#",
             "######################.#",
             "#d.....................#",
             "########################"]

char_maze = ["########################",
             "#...............b.C.D.f#",
             "#.######################",
             "#.....@.a.B.c.d.A.e.F.g#",
             "########################"]

char_maze = ["#################", # Hard one, is a bit slow
             "#i.G..c...e..H.p#",
             "########.########",
             "#j.A..b...f..D.o#",
             "########@########",
             "#k.E..a...g..B.n#",
             "########.########",
             "#l.F..d...h..C.m#",
             "#################"]

char_maze = ["########################",
             "#@..............ac.GI.b#",
             "###d#e#f################",
             "###A#B#C################",
             "###g#h#i################",
             "########################"]

char_maze = ["#################################################################################",
             "#...#.....#......c....#...#.Q.......#...#f#a....#..j..........#...............#.#",
             "#.#.#.#.###.#######.#.#.#.#.###.###.#.#.#.#.###.#.#######.###.#.#.###########.#.#",
             "#.#.#v#.....#.....#.#...#.#.#...#...#.#.#.#...#.......#...#.#.#.#...#...#.....N.#",
             "###.#.#######.###.#X#######.#.###.###.###.###.#########R###.#.#.###.#.#.#.#######",
             "#.K.#.....#...#...#.....#...#.#.....#...#.....#.......#.#.#...#...#.#.#.#...#...#",
             "#.#.#####.#.###.#######.#.###.#####.#.#.#.#####.#####.#.#.#.#####.#.#.#.#####.#.#",
             "#.#.#.U.#.#.#...#...#...#...#...#...#.#.#.#...#.#...#...#.#.....#.#...#.......#.#",
             "#.#.###.#.#.#.#####.#.#.###.###.#.#####.#.#.#.#.###.#####.#####.#####.#####.###.#",
             "#.#.#...#...#.....#.#.#...#.#.#.#.....#.#.#.#.#.Y.#.....#.....#.....#.#...#...#.#",
             "#.#.#.#.#########.#.#.#####.#.#.#####.#.#.###.###.###.#.###.#.#####.###.#.#####.#",
             "#.#...#.#.........#.#.........#.#...#...#.#...#...#...#.#...#.#...#...#.#.......#",
             "#.#######.#########.###########.###.###.#.#.###.###.###.#.###.###.###.#.#######.#",
             "#.....#...#.#...........#.......#.....#.#...#...#.#...#...#.........#.#.#...#...#",
             "#.###.#.###.#.#########.#.#######.#####.#####.###.#.#.###############.#.#.#.#.###",
             "#.#.#.#...#.....#.......#.#.............#.....#.....#.....#.....#...#.#...#.#...#",
             "#.#.#.###.#####.#.#######.#.#####.#####.#.#####.#####.###.#.###.#.#.#.#.###.#####",
             "#.#.#...#.O...#.#.#.......#.#...#.#...#.#...#...#...#...#...#...#.#...#...#.....#",
             "#.#.#.#######.###.#.#####.###.#.#.#.#.#.#.#.#####.#.###.#####.###.#######.#####.#",
             "#.#.#.......#.....#.....#t#...#.#.#.#.#.#.#.#.....#.#.......#.....#.....#.#.....#",
             "#.#.#####.#######.#####.###.###.###.#.#.###.#.#####.###########.###.###.###.###.#",
             "#.......#.........#...#...#.#.#.....#.#.#...#.....#.#.....#...#.....#...#...#.#.#",
             "#######.###########.#####.#.#.#######.#.#.#####.###.#.###.#.###.#####.###.###.#.#",
             "#.......#.......#...#...#.#...#...#...#.#.#.....#...#.#.#.#...#.#...#.....#.#...#",
             "#.#####.#.#######.###.#.#.###.#.###.#####.#.#####.###.#.#.###.###.#.#.#####.#.###",
             "#.#...#...#...#...#...#.#.#...#...#.....#...#...#.......#...#...#.#.#.#...#...#.#",
             "#.#.#.#####.#.#.###.###.#.#.#####.#####.#P###.#.#######.###.###.#.#.###.#.###.#.#",
             "#.#.#.......#...#...#.....#.#.....#...#.#.#i..#...#...#.#.....#...#.#...#...#...#",
             "###.###############.#######.#.#.#.###.#.#.#####.###.#.###.#########.#.#####.###.#",
             "#...#.............#...#...#.#.#.#.#...#.#.....#.#...#.....#.......#.#...#...#.#.#",
             "#.###.#######.###.#.#.#.#.#.###.#.#.#.#.#####.#.#.#.#######.#####.#.###.###.#.#.#",
             "#.#.........#.#...#.#...#.......#...#.#.#.....#.#.#.#...#...#...#.#...#...#.#.#.#",
             "#.###########.#.###.###############.###.#.#####.#.###.#.#.###.###.###.###.#.#.#Z#",
             "#...#.........#.#.#.#.#.......#.....#...#.#.....#.#...#...#...#.....#.....#.#...#",
             "###.#.#########.#.#.#.#.#####.#.#####.#.#.###.###.#.#########.#.###.#######.#.###",
             "#.#...#.....#...#.#...#.#...#.#...#...#.#.#...#...#.#.......#.#...#.#.......#.#.#",
             "#.#####.#.###.###.###.#.#.#.#.#####.###.#.#.###.#.#.###.###.#.###.#.#.#######.#.#",
             "#.....#.#...#.#.......#...#.#.#...#.#...#.#.#...#.#.....#...#...#.#.#.#.....#..x#",
             "#.#####.###.#.#############.#.#.#.#.#.###.#.#.###########.###.#.#.###.#.#.#####.#",
             "#.........#.................#...#...#.......#.................#.#.....#.#.......#",
             "#######################################.@.#######################################",
             "#.......#.................#...............#.....#...........#.........#...#.....#",
             "#.#####.#.#########.#####.#.###########.#.#.###.#.#.#######.#.#.#######.#.###.#.#",
             "#...#.#.#.#...#...#.....#.#...#...#.....#.#...#...#.....#...#.#...#.....#.#...#.#",
             "###.#.#.###.#.#.#.#####.#.#####.#.#.###.#.###.#########.#####.###.#.#####.#V#####",
             "#...#.#...#.#.#.#.....#.#.#.....#.#.#...#...#.#.....#.#.....#...#...#...#.#.....#",
             "#.###.###.#.#.#.#####.#.#.#.#####.#.#.###.###.#.#.#.#.#####.###.#######.#.#####.#",
             "#...#...#.#.#.#.....#...#.#.#.....#.#...#.#...#.#.#.W.#...#...#.........#.....#.#",
             "#.#.###.#G#.#.#####.#####.#.#.#####.#####.#.#####.###.###.###.#####.#########.#.#",
             "#.#.#...#...#.#.....#...#...#.#.........#...#...#...#.......#.....#.#.....#...#.#",
             "###.#.#######.#.#######.#####.#.#######.#.###.#.###.#######.#.#####.#.###.#.###.#",
             "#...#.#.....#...#...........#.#.....#...#p....#...#.....#...#......r#.#.....#...#",
             "#.###.#.#.#######.###.#.#####.#.#####.#.#########.#.###.#E###########.#######.#.#",
             "#.#.....#.#.........#.#.#...#.#.#.....#.#...#...#.#.#...#...#.S.....#...#.....#.#",
             "#.#######.#.#########.#.#.#.#.#.#.#######.###.#.#.#.#.#####.###.#######.#.###.###",
             "#.L.....#.#z....#.....#.#.#.#.#.#...#...#.#...#...#.#.#.........#.......#.#.#...#",
             "#.#####.#.#####.#.#####.#.#.#.#####.#.#.#.#.#########.#.#########.#######.#.###.#",
             "#.#...#.#...#...#.....#.#.#...#.....#.#.#.#.......#...#.#...#.....#.#..o#.#.#...#",
             "#.#.###.###.#.#######.###.#####.#####.#.#.#######.#.###.#.#.#.#####.#.#.#.#.#.###",
             "#.#.#...#...#.......#...#.#.#...I.....#.#...#...#.#...#...#b#.#.......#.#...#...#",
             "#.#.#.###.#####.#######.#.#.#.#########.#.#.###.#.###.#######.#.#######.###.###.#",
             "#.#.#.#.#.......#.....#.#.#......y..#.#.#.#.....#...#...#...#.#..l#..g#.#.....#.#",
             "#.#.#.#.#.#######H#####.#.###.#####.#.#.#.###.#####.#.#.#.#.#####.#.#.#.#.#####.#",
             "#...#.#.#...#...#.#..h#.#...#.#...#...#.#.#...#.....#.#.#.#.....#.#.#.#.#.#.#...#",
             "#.###.#.###.#.#.#.#.#.#.###.###.#.#####.#.#####.#######.#.###.#.#.#.#.#.#.#.#.#.#",
             "#.#...#.......#.#...#.#.....#...#...#...#...#...#.....#.#...#.#.#.#.#...#...#.#.#",
             "#.#.###########.#####D#####.#.#####.#.#.#.#.#.###.###.#.###.#.#.#.#.#######.#.#.#",
             "#.#.#.....#.......#.#.....#...#.....#.#.#.#.#.#...#...#.....#.#.#.#...#.....#.#.#",
             "#M#.#.###.#######.#.#####.#####.#####.#####.#.#.###.###.#####.###.###.#.#####.#.#",
             "#.#.....#.#.....#.......#...#.#.#.......#...#...#...#...#...#.......#...#...#.#.#",
             "#.#######.#.###.#.#########.#A#.###.###.#.#######.#######.#.#.###########.#.#.#.#",
             "#.#w....#.#...#.#.#....d....#.#...#...#.#.......#...#...#.#.#..m#.....#...#...#.#",
             "#.#.###.#.###.#.###.#########.###.#####.#.###.#####.#.#.#.#.###.#.###.#.#######.#",
             "#k#...#.#u#...#...B.#.....#.....#.....#.#...#.....#...#.#.#...#.#.#.#...#..n#...#",
             "#.###.#.#.#.#########.###.#.#.#.#####J#.###.###.#.#####.#.###.###.#.#######.#.###",
             "#.#...#...#...#...#...#.#...#.#.....#.#.#...#.#.#.....#.#...#...#.#.........#.#.#",
             "###.#########.#.###F###.#####.#######.#.#.###.#.#####T#.###.###.#.#.#.#####.#.#.#",
             "#...#.......#s#...#.........#...#...#...#.#...#.....#.#...#...#.#q#.#.#.....#...#",
             "#.###.#####.#.#.#.#########.###.#.#.###.#.#.#.#####.#####.###.#.#.#.#.#########C#",
             "#..e......#...#.#.............#...#.....#...#.....#...........#...#.#...........#",
             "#################################################################################"]

start_pos = {}
goal_pos = {}
road_cells = []
keys = []
doors = []
lower_letters = 'abcdefghijklmnopqrstuvwxyz'
upper_letters = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# Parse maze, non-wall cells are considered roads.
for r in range(len(char_maze[:])):
    for c in range(len(char_maze[0])):
        char = char_maze[r][c]
        if not char == '#': 
            road_cells.append((r,c))
        if char == '@':
            start_pos[char] = (r,c)
        if char in lower_letters:
            keys.append(char)
            start_pos[char] = (r,c)
        if char in upper_letters:
            doors.append(char)


depends = {}
steps_from_to = {}
bonus_keys_from_to = {}

for source, destination in permutations(start_pos.keys(),2):
    print(f"\n{source=}, \t{destination=}", end='', flush=True)
    # Explore maze from, to
    frontier = [start_pos[source]]
    visited = {} # cell : previous cell
    #visited[start_pos[source]] = start_pos[source]
    # Backtracking algorithm
    while frontier:
        f = frontier.pop(0)
        up = (f[0]-1,f[1])
        down = (f[0]+1,f[1])
        left = (f[0],f[1]-1)
        right = (f[0],f[1]+1)
        if (up    not in visited) and (up    in road_cells): 
            visited[up]    = f
            frontier.append(up)    # Add key, and from where it came from
        if (down  not in visited) and (down  in road_cells): 
            visited[down]  = f
            frontier.append(down)  # Add key, and from where it came from
        if (left  not in visited) and (left  in road_cells): 
            visited[left]  = f
            frontier.append(left)  # Add key, and from where it came from
        if (right not in visited) and (right in road_cells): 
            visited[right] = f
            frontier.append(right) # Add key, and from where it came from
    # Backtrack, and record dependencies
    pos = start_pos[destination]
    steps = 0
    bonus_keys_from_to[source,destination] = set()
    if source=='@':
        depends[destination] = set()
    if pos not in visited:
        steps = -1
    else:
        while pos != start_pos[source]:
            pos = visited[pos]
            # Add dependencies if we crossed a door
            C = char_maze[pos[0]][pos[1]]
            if C in doors:
                if source=='@':
                    depends[destination].add(C.lower())
            # Add "keys captured along they way kind of thing"
            if C in keys and C not in (source):
                bonus_keys_from_to[source,destination].add(C)
                # TRY TODO CHECK: to reduce tree, only allow first visible key to be reached (not the ones behind, even if there are no doors)
                if source=='@':
                    depends[destination].add(C)
            steps += 1
    steps_from_to[source,destination] = steps
    print(f", \t{steps=}",end='',flush=True)
    print(f", \t{bonus_keys_from_to[source,destination]=}",end='',flush=True)
    if source=='@':
        print(f", \t{depends[destination]=}",end='',flush=True)
print('\n')
print(steps_from_to)
print(depends)
# Out:
# ion]={'e', 'u', 'w'}
# source='s', 	destination='f', 	steps=472, 	bonus_keys_from_to[source,destination]={'a', 'j', 'w', 'u', 'e'}
# source='s', 	destination='a', 	steps=458, 	bonus_keys_from_to[source,destination]={'j', 'u', 'w', 'e'}
# source='s', 	destination='j', 	steps=446, 	bonus_keys_from_to[source,destination]={'e', 'u', 'w'}
# source='s', 	destination='v', 	steps=570, 	bonus_keys_from_to[source,destination]={'e', 'u', 'c', 'w'}
# source='s', 	destination='t', 	steps=486, 	bonus_keys_from_to[source,destination]={'e', 'u', 'w'}
# source='s', 	destination='i', 	steps=392, 	bonus_keys_from_to[source,destination]={'e', 'u', 'w'}
# source='s', 	destination='x', 	steps=542, 	bonus_keys_from_to[source,destination]={'e', 'u', 'w'}
# source='s', 	destination='@', 	steps=364, 	bonus_keys_from_to[source,destination]={'e', 'u', 'w'}
# source='s', 	destination='p', 	steps=374, 	bonus_keys_from_to[source,destination]={'e', 'u', 'w'}
# source='s', 	destination='r', 	steps=424, 	bonus_keys_from_to[source,destination]={'e', 'u', 'w'}
# source='s', 	destination='z', 	steps=288, 	bonus_keys_from_to[source,destination]={'e', 'u', 'w'}
# source='s', 	destination='o', 	steps=618, 	bonus_keys_from_to[source,destination]={'p', 'g', 'w', 'q', 'u', 'e'}
# source='s', 	destination='b', 	steps=744, 	bonus_keys_from_to[source,destination]={'p', 'g', 'w', 'q', 'u', 'l', 'e', 'o'}
# source='s', 	destination='y', 	steps=332, 	bonus_keys_from_to[source,destination]={'e', 'u', 'w'}
# source='s', 	destination='l', 	steps=632, 	bonus_keys_from_to[source,destination]={'p', 'g', 'w', 'q', 'u', 'e', 'o'}
# source='s', 	destination='g', 	steps=604, 	bonus_keys_from_to[source,destination]={'p', 'w', 'q', 'u', 'e'}
# source='s', 	destination='h', 	steps=50, 	bonus_keys_from_to[source,destination]={'d'}
# source='s', 	destination='w', 	steps=32, 	bonus_keys_from_to[source,destination]={'e'}
# source='s', 	destination='d', 	steps=32, 	bonus_keys_from_to[source,destination]=set()
# source='s', 	destination='m', 	steps=648, 	bonus_keys_from_to[source,destination]={'p', 'g', 'w', 'q', 'u', 'l', 'e', 'o'}
# source='s', 	destination='k', 	steps=100, 	bonus_keys_from_to[source,destination]={'e', 'u', 'w'}
# source='s', 	destination='u', 	steps=44, 	bonus_keys_from_to[source,destination]={'e', 'w'}
# source='s', 	destination='n', 	steps=586, 	bonus_keys_from_to[source,destination]={'p', 'w', 'q', 'u', 'e'}
# source='s', 	destination='q', 	steps=508, 	bonus_keys_from_to[source,destination]={'e', 'u', 'p', 'w'}
# source='s', 	destination='e', 	steps=16, 	bonus_keys_from_to[source,destination]=set()
# source='q', 	destination='c', 	steps=336, 	bonus_keys_from_to[source,destination]={'p'}
# source='q', 	destination='f', 	steps=252, 	bonus_keys_from_to[source,destination]={'j', 'a', 'p'}
# source='q', 	destination='a', 	steps=238, 	bonus_keys_from_to[source,destination]={'j', 'p'}
# source='q', 	destination='j', 	steps=226, 	bonus_keys_from_to[source,destination]={'p'}
# source='q', 	destination='v', 	steps=354, 	bonus_keys_from_to[source,destination]={'c', 'p'}
# source='q', 	destination='t', 	steps=270, 	bonus_keys_from_to[source,destination]={'p'}
# source='q', 	destination='i', 	steps=172, 	bonus_keys_from_to[source,destination]={'p'}
# source='q', 	destination='x', 	steps=322, 	bonus_keys_from_to[source,destination]={'p'}
# source='q', 	destination='@', 	steps=146, 	bonus_keys_from_to[source,destination]={'p'}
# source='q', 	destination='p', 	steps=134, 	bonus_keys_from_to[source,destination]=set()
# source='q', 	destination='r', 	steps=188, 	bonus_keys_from_to[source,destination]={'p'}
# source='q', 	destination='z', 	steps=304, 	bonus_keys_from_to[source,destination]={'p'}
# source='q', 	destination='o', 	steps=110, 	bonus_keys_from_to[source,destination]={'g'}
# source='q', 	destination='b', 	steps=236, 	bonus_keys_from_to[source,destination]={'g', 'o', 'l'}
# source='q', 	destination='y', 	steps=192, 	bonus_keys_from_to[source,destination]={'p'}
# source='q', 	destination='l', 	steps=124, 	bonus_keys_from_to[source,destination]={'g', 'o'}
# source='q', 	destination='g', 	steps=96, 	bonus_keys_from_to[source,destination]=set()
# source='q', 	destination='h', 	steps=558, 	bonus_keys_from_to[source,destination]={'d', 'p', 's', 'w', 'u', 'e'}
# source='q', 	destination='w', 	steps=476, 	bonus_keys_from_to[source,destination]={'u', 'p'}
# source='q', 	destination='d', 	steps=540, 	bonus_keys_from_to[source,destination]={'p', 's', 'w', 'u', 'e'}
# source='q', 	destination='m', 	steps=140, 	bonus_keys_from_to[source,destination]={'g', 'o', 'l'}
# source='q', 	destination='k', 	steps=444, 	bonus_keys_from_to[source,destination]={'p'}
# source='q', 	destination='u', 	steps=464, 	bonus_keys_from_to[source,destination]={'p'}
# source='q', 	destination='n', 	steps=78, 	bonus_keys_from_to[source,destination]=set()
# source='q', 	destination='s', 	steps=508, 	bonus_keys_from_to[source,destination]={'e', 'u', 'w', 'p'}
# source='q', 	destination='e', 	steps=492, 	bonus_keys_from_to[source,destination]={'u', 'w', 'p'}
# source='e', 	destination='c', 	steps=536, 	bonus_keys_from_to[source,destination]={'u', 'w'}
# source='e', 	destination='f', 	steps=456, 	bonus_keys_from_to[source,destination]={'u', 'j', 'a', 'w'}
# source='e', 	destination='a', 	steps=442, 	bonus_keys_from_to[source,destination]={'j', 'u', 'w'}
# source='e', 	destination='j', 	steps=430, 	bonus_keys_from_to[source,destination]={'u', 'w'}
# source='e', 	destination='v', 	steps=554, 	bonus_keys_from_to[source,destination]={'u', 'c', 'w'}
# source='e', 	destination='t', 	steps=470, 	bonus_keys_from_to[source,destination]={'u', 'w'}
# source='e', 	destination='i', 	steps=376, 	bonus_keys_from_to[source,destination]={'u', 'w'}
# source='e', 	destination='x', 	steps=526, 	bonus_keys_from_to[source,destination]={'u', 'w'}
# source='e', 	destination='@', 	steps=348, 	bonus_keys_from_to[source,destination]={'u', 'w'}
# source='e', 	destination='p', 	steps=358, 	bonus_keys_from_to[source,destination]={'u', 'w'}
# source='e', 	destination='r', 	steps=408, 	bonus_keys_from_to[source,destination]={'u', 'w'}
# source='e', 	destination='z', 	steps=272, 	bonus_keys_from_to[source,destination]={'u', 'w'}
# source='e', 	destination='o', 	steps=602, 	bonus_keys_from_to[source,destination]={'p', 'g', 'w', 'q', 'u'}
# source='e', 	destination='b', 	steps=728, 	bonus_keys_from_to[source,destination]={'p', 'g', 'w', 'q', 'u', 'l', 'o'}
# source='e', 	destination='y', 	steps=316, 	bonus_keys_from_to[source,destination]={'u', 'w'}
# source='e', 	destination='l', 	steps=616, 	bonus_keys_from_to[source,destination]={'p', 'g', 'w', 'q', 'u', 'o'}
# source='e', 	destination='g', 	steps=588, 	bonus_keys_from_to[source,destination]={'q', 'u', 'p', 'w'}
# source='e', 	destination='h', 	steps=66, 	bonus_keys_from_to[source,destination]={'s', 'd'}
# source='e', 	destination='w', 	steps=16, 	bonus_keys_from_to[source,destination]=set()
# source='e', 	destination='d', 	steps=48, 	bonus_keys_from_to[source,destination]={'s'}
# source='e', 	destination='m', 	steps=632, 	bonus_keys_from_to[source,destination]={'p', 'g', 'w', 'q', 'u', 'l', 'o'}
# source='e', 	destination='k', 	steps=84, 	bonus_keys_from_to[source,destination]={'u', 'w'}
# source='e', 	destination='u', 	steps=28, 	bonus_keys_from_to[source,destination]={'w'}
# source='e', 	destination='n', 	steps=570, 	bonus_keys_from_to[source,destination]={'q', 'u', 'p', 'w'}
# source='e', 	destination='s', 	steps=16, 	bonus_keys_from_to[source,destination]=set()
# source='e', 	destination='q', 	steps=492, 	bonus_keys_from_to[source,destination]={'u', 'p', 'w'}
#
# {('c', 'f'): 296, ('c', 'a'): 282, ('c', 'j'): 270, ('c', 'v'): 18, ('c', 't'): 70, ('c', 'i'): 216, ('c', 'x'): 366, ('c', '@'): 190, ('c', 'p'): 202, ('c', 'r'): 252, ('c', 'z'): 348, ('c', 'o'): 446, ('c', 'b'): 572, ('c', 'y'): 236, ('c', 'l'): 460, ('c', 'g'): 432, ('c', 'h'): 602, ('c', 'w'): 520, ('c', 'd'): 584, ('c', 'm'): 476, ('c', 'k'): 488, ('c', 'u'): 508, ('c', 'n'): 414, ('c', 's'): 552, ('c', 'q'): 336, ('c', 'e'): 536, ('f', 'c'): 296, ('f', 'a'): 14, ('f', 'j'): 26, ('f', 'v'): 314, ('f', 't'): 230, ('f', 'i'): 132, ('f', 'x'): 134, ('f', '@'): 108, ('f', 'p'): 118, ('f', 'r'): 168, ('f', 'z'): 268, ('f', 'o'): 362, ('f', 'b'): 488, ('f', 'y'): 156, ('f', 'l'): 376, ('f', 'g'): 348, ('f', 'h'): 522, ('f', 'w'): 440, ('f', 'd'): 504, ('f', 'm'): 392, ('f', 'k'): 408, ('f', 'u'): 428, ('f', 'n'): 330, ('f', 's'): 472, ('f', 'q'): 252, ('f', 'e'): 456, ('a', 'c'): 282, ('a', 'f'): 14, ('a', 'j'): 12, ('a', 'v'): 300, ('a', 't'): 216, ('a', 'i'): 118, ('a', 'x'): 120, ('a', '@'): 94, ('a', 'p'): 104, ('a', 'r'): 154, ('a', 'z'): 254, ('a', 'o'): 348, ('a', 'b'): 474, ('a', 'y'): 142, ('a', 'l'): 362, ('a', 'g'): 334, ('a', 'h'): 508, ('a', 'w'): 426, ('a', 'd'): 490, ('a', 'm'): 378, ('a', 'k'): 394, ('a', 'u'): 414, ('a', 'n'): 316, ('a', 's'): 458, ('a', 'q'): 238, ('a', 'e'): 442, ('j', 'c'): 270, ('j', 'f'): 26, ('j', 'a'): 12, ('j', 'v'): 288, ('j', 't'): 204, ('j', 'i'): 106, ('j', 'x'): 108, ('j', '@'): 82, ('j', 'p'): 92, ('j', 'r'): 142, ('j', 'z'): 242, ('j', 'o'): 336, ('j', 'b'): 462, ('j', 'y'): 130, ('j', 'l'): 350, ('j', 'g'): 322, ('j', 'h'): 496, ('j', 'w'): 414, ('j', 'd'): 478, ('j', 'm'): 366, ('j', 'k'): 382, ('j', 'u'): 402, ('j', 'n'): 304, ('j', 's'): 446, ('j', 'q'): 226, ('j', 'e'): 430, ('v', 'c'): 18, ('v', 'f'): 314, ('v', 'a'): 300, ('v', 'j'): 288, ('v', 't'): 88, ('v', 'i'): 234, ('v', 'x'): 384, ('v', '@'): 208, ('v', 'p'): 220, ('v', 'r'): 270, ('v', 'z'): 366, ('v', 'o'): 464, ('v', 'b'): 590, ('v', 'y'): 254, ('v', 'l'): 478, ('v', 'g'): 450, ('v', 'h'): 620, ('v', 'w'): 538, ('v', 'd'): 602, ('v', 'm'): 494, ('v', 'k'): 506, ('v', 'u'): 526, ('v', 'n'): 432, ('v', 's'): 570, ('v', 'q'): 354, ('v', 'e'): 554, ('t', 'c'): 70, ('t', 'f'): 230, ('t', 'a'): 216, ('t', 'j'): 204, ('t', 'v'): 88, ('t', 'i'): 150, ('t', 'x'): 300, ('t', '@'): 124, ('t', 'p'): 136, ('t', 'r'): 186, ('t', 'z'): 282, ('t', 'o'): 380, ('t', 'b'): 506, ('t', 'y'): 170, ('t', 'l'): 394, ('t', 'g'): 366, ('t', 'h'): 536, ('t', 'w'): 454, ('t', 'd'): 518, ('t', 'm'): 410, ('t', 'k'): 422, ('t', 'u'): 442, ('t', 'n'): 348, ('t', 's'): 486, ('t', 'q'): 270, ('t', 'e'): 470, ('i', 'c'): 216, ('i', 'f'): 132, ('i', 'a'): 118, ('i', 'j'): 106, ('i', 'v'): 234, ('i', 't'): 150, ('i', 'x'): 202, ('i', '@'): 28, ('i', 'p'): 38, ('i', 'r'): 88, ('i', 'z'): 188, ('i', 'o'): 282, ('i', 'b'): 408, ('i', 'y'): 76, ('i', 'l'): 296, ('i', 'g'): 268, ('i', 'h'): 442, ('i', 'w'): 360, ('i', 'd'): 424, ('i', 'm'): 312, ('i', 'k'): 328, ('i', 'u'): 348, ('i', 'n'): 250, ('i', 's'): 392, ('i', 'q'): 172, ('i', 'e'): 376, ('x', 'c'): 366, ('x', 'f'): 134, ('x', 'a'): 120, ('x', 'j'): 108, ('x', 'v'): 384, ('x', 't'): 300, ('x', 'i'): 202, ('x', '@'): 178, ('x', 'p'): 188, ('x', 'r'): 238, ('x', 'z'): 338, ('x', 'o'): 432, ('x', 'b'): 558, ('x', 'y'): 226, ('x', 'l'): 446, ('x', 'g'): 418, ('x', 'h'): 592, ('x', 'w'): 510, ('x', 'd'): 574, ('x', 'm'): 462, ('x', 'k'): 478, ('x', 'u'): 498, ('x', 'n'): 400, ('x', 's'): 542, ('x', 'q'): 322, ('x', 'e'): 526, ('@', 'c'): 190, ('@', 'f'): 108, ('@', 'a'): 94, ('@', 'j'): 82, ('@', 'v'): 208, ('@', 't'): 124, ('@', 'i'): 28, ('@', 'x'): 178, ('@', 'p'): 12, ('@', 'r'): 62, ('@', 'z'): 160, ('@', 'o'): 256, ('@', 'b'): 382, ('@', 'y'): 48, ('@', 'l'): 270, ('@', 'g'): 242, ('@', 'h'): 414, ('@', 'w'): 332, ('@', 'd'): 396, ('@', 'm'): 286, ('@', 'k'): 300, ('@', 'u'): 320, ('@', 'n'): 224, ('@', 's'): 364, ('@', 'q'): 146, ('@', 'e'): 348, ('p', 'c'): 202, ('p', 'f'): 118, ('p', 'a'):  ...
# {'c': {'q', 'x'}, 'f': {'a', 'p', 'r', 'j', 'y'}, 'a': {'r', 'j', 'p', 'y'}, 'j': {'r', 'p', 'y'}, 'v': {'x', 'q', 'c'}, 't': set(), 'i': set(), 'x': {'z', 'r', 'p', 'y'}, 'p': set(), 'r': set(), 'z': {'j', 'i'}, 'o': {'q', 'g', 'p'}, 'b': {'p', 'g', 'w', 'q', 'l', 'e', 'o'}, 'y': set(), 'l': {'q', 'g', 'o', 'p'}, 'g': {'q', 'p'}, 'h': {'d', 's', 'j', 'g', 'w', 'u', 'l', 'b', 'i', 'e'}, 'w': {'j', 'g', 'u', 'i', 'l'}, 'd': {'s', 'j', 'g', 'w', 'u', 'l', 'b', 'i', 'e'}, 'm': {'p', 'g', 'q', 'l', 'o'}, 'k': {'j', 'g', 'i', 'm'}, 'u': {'j', 'g', 'i', 'l'}, 'n': {'q', 'c', 'p'}, 's': {'j', 'g', 'w', 'u', 'l', 'i', 'e'}, 'q': {'p'}, 'e': {'j', 'g', 'w', 'u', 'l', 'i'}}

# %%
# Iterative solution to get all keys in the least amount of steps
stateNT = namedtuple('state','owned_keys reachable_keys steps current_position')
owned_keys = set()
state = stateNT( owned_keys = owned_keys, 
                 reachable_keys = get_reachable_keys(owned_keys, depends), 
                 steps = 0,
                 current_position = '@')

Q = deque()
Q.append(state)
solutions = []
sets_list = []
steps_list = [] # Min steps associated to get that set of keys (kill early combinations that took too many steps)
heads_list = [] # Position associated with a set of keys
# BFS, try to get all keys!
iterations = 0
min_steps = 10000
n_solutions = 0
keys_target = len(keys)
max_got_keys = 0
killed_branches = 0
while Q:
    iterations+=1
    S = Q.popleft()
    if iterations%10000==0:
        print(f'{iterations=}, {n_solutions=}, {min_steps=}, {max_got_keys=}/{keys_target}, {len(Q)=}, {killed_branches=}')
    assert(isinstance(S.reachable_keys, set))
    assert(isinstance(S.owned_keys, set))
    for k in S.reachable_keys:
        steps = S.steps
        steps += steps_from_to[S.current_position, k]
        #print(f"Go from {S.current_position} to {k}")
        owned_keys = deepcopy(S.owned_keys)
        # This does not take into account the keys that may be collected on the way to another key
        # For a first solution it's ok, because  when going from a to c in a-b-c
        # the a-c-b solution (fake) will be longer than a-b-c and discarded later on
        # Problem is that it adds many more iterations. Should consider to add a "keys captured
        # along the way to destination" kind of thing
        owned_keys.add(k)
        owned_keys.union(bonus_keys_from_to[S.current_position, k])
        current_position = k
        reachable_keys = get_reachable_keys(owned_keys, depends)
        new_state = stateNT(owned_keys = owned_keys, 
                            reachable_keys = reachable_keys, 
                            steps = steps, 
                            current_position = current_position)
        #print(new_state)
        continue_branch = True
        if owned_keys not in sets_list:
            sets_list.append(owned_keys)
            steps_list.append(steps)
            heads_list.append(current_position)
            max_got_keys = max(max_got_keys, len(owned_keys))
        else:
            iset = sets_list.index(owned_keys)
            # if steps >= steps_list[iset] and current_position==heads_list[iset]:
            if  ((steps >= steps_list[iset] and current_position==heads_list[iset]) or 
                steps > 3864): # We know we can do better than this
                killed_branches+=1
                continue_branch = False
            else:
                steps_list[iset] = steps
                heads_list[iset] = current_position
        if not new_state.reachable_keys:
            # There are no more reachable keys! We may have them all :)
            #print("ONE SOLUTION WAS FOUND!!!")
            #print(new_state)
            #solutions.append(new_state)
            min_steps = min(min_steps, steps)
            n_solutions += 1
        else:
            if continue_branch:
                if Q and (steps < Q[0].steps): # Prioritise shortest solutions
                    Q.appendleft(deepcopy(new_state))
                else:
                    Q.append(deepcopy(new_state))

# min_steps = 1e10
# for s in solutions:
#     if s.steps<min_steps:
#         min_steps = s.steps

print(f"Solution part 1 is: {min_steps=} among {n_solutions=} with a total of {iterations=}")
# Out:
# 4, max_got_keys=26/26, len(Q)=1031746, killed_branches=8255992
# iterations=4460000, n_solutions=16, min_steps=3864, max_got_keys=26/26, len(Q)=1024489, killed_branches=8280954
# iterations=4470000, n_solutions=17, min_steps=3864, max_got_keys=26/26, len(Q)=1017565, killed_branches=8304754
# iterations=4480000, n_solutions=17, min_steps=3864, max_got_keys=26/26, len(Q)=1009545, killed_branches=8326402
# iterations=4490000, n_solutions=17, min_steps=3864, max_got_keys=26/26, len(Q)=1002297, killed_branches=8348553
# iterations=4500000, n_solutions=17, min_steps=3864, max_got_keys=26/26, len(Q)=995968, killed_branches=8369887
# iterations=4510000, n_solutions=17, min_steps=3864, max_got_keys=26/26, len(Q)=990236, killed_branches=8390200
# iterations=4520000, n_solutions=17, min_steps=3864, max_got_keys=26/26, len(Q)=984492, killed_branches=8411153
# iterations=4530000, n_solutions=17, min_steps=3864, max_got_keys=26/26, len(Q)=978075, killed_branches=8431532
# iterations=4540000, n_solutions=17, min_steps=3864, max_got_keys=26/26, len(Q)=971583, killed_branches=8451855
# iterations=4550000, n_solutions=17, min_steps=3864, max_got_keys=26/26, len(Q)=964878, killed_branches=8474535
# iterations=4560000, n_solutions=17, min_steps=3864, max_got_keys=26/26, len(Q)=961598, killed_branches=8495174
# iterations=4570000, n_solutions=17, min_steps=3864, max_got_keys=26/26, len(Q)=958646, killed_branches=8515800
# iterations=4580000, n_solutions=17, min_steps=3864, max_got_keys=26/26, len(Q)=954237, killed_branches=8538363
# iterations=4590000, n_solutions=17, min_steps=3864, max_got_keys=26/26, len(Q)=948150, killed_branches=8559261
# iterations=4600000, n_solutions=17, min_steps=3864, max_got_keys=26/26, len(Q)=943411, killed_branches=8578712
# iterations=4610000, n_solutions=17, min_steps=3864, max_got_keys=26/26, len(Q)=939117, killed_branches=8600185
# iterations=4620000, n_solutions=17, min_steps=3864, max_got_keys=26/26, len(Q)=932745, killed_branches=8622828
# iterations=4630000, n_solutions=17, min_steps=3864, max_got_keys=26/26, len(Q)=926242, killed_branches=8649065
# iterations=4640000, n_solutions=17, min_steps=3864, max_got_keys=26/26, len(Q)=919068, killed_branches=8674035
# iterations=4650000, n_solutions=17, min_steps=3864, max_got_keys=26/26, len(Q)=912687, killed_branches=8700129
# iterations=4660000, n_solutions=19, min_steps=3864, max_got_keys=26/26, len(Q)=905163, killed_branches=8725106
# iterations=4670000, n_solutions=20, min_steps=3864, max_got_keys=26/26, len(Q)=898273, killed_branches=8749192
# iterations=4680000, n_solutions=20, min_steps=3864, max_got_keys=26/26, len(Q)=894235, killed_branches=8769857
# iterations=4690000, n_solutions=20, min_steps=3864, max_got_keys=26/26, len(Q)=888442, killed_branches=8791870
# iterations=4700000, n_solutions=20, min_steps=3864, max_got_keys=26/26, len(Q)=882183, killed_branches=8813925
# iterations=4710000, n_solutions=20, min_steps=3864, max_got_keys=26/26, len(Q)=875898, killed_branches=8834616
# iterations=4720000, n_solutions=20, min_steps=3864, max_got_keys=26/26, len(Q)=870148, killed_branches=8856399
# iterations=4730000, n_solutions=21, min_steps=3864, max_got_keys=26/26, len(Q)=863425, killed_branches=8877532
# iterations=4740000, n_solutions=21, min_steps=3864, max_got_keys=26/26, len(Q)=857459, killed_branches=8898930
# iterations=4750000, n_solutions=21, min_steps=3864, max_got_keys=26/26, len(Q)=853506, killed_branches=8921245
# iterations=4760000, n_solutions=21, min_steps=3864, max_got_keys=26/26, len(Q)=847969, killed_branches=8944209
# iterations=4770000, n_solutions=21, min_steps=3864, max_got_keys=26/26, len(Q)=842707, killed_branches=8965670
# iterations=4780000, n_solutions=21, min_steps=3864, max_got_keys=26/26, len(Q)=836079, killed_branches=8987608
# iterations=4790000, n_solutions=21, min_steps=3864, max_got_keys=26/26, len(Q)=829499, killed_branches=9008275
# iterations=4800000, n_solutions=21, min_steps=3864, max_got_keys=26/26, len(Q)=823203, killed_branches=9028875
# iterations=4810000, n_solutions=21, min_steps=3864, max_got_keys=26/26, len(Q)=820957, killed_branches=9048787
# iterations=4820000, n_solutions=21, min_steps=3864, max_got_keys=26/26, len(Q)=815259, killed_branches=9068898
# iterations=4830000, n_solutions=21, min_steps=3864, max_got_keys=26/26, len(Q)=812156, killed_branches=9088792
# iterations=4840000, n_solutions=21, min_steps=3864, max_got_keys=26/26, len(Q)=805988, killed_branches=9108630
# iterations=4850000, n_solutions=21, min_steps=3864, max_got_keys=26/26, len(Q)=799091, killed_branches=9128685
# iterations=4860000, n_solutions=21, min_steps=3864, max_got_keys=26/26, len(Q)=791948, killed_branches=9147991
# iterations=4870000, n_solutions=21, min_steps=3864, max_got_keys=26/26, len(Q)=783790, killed_branches=9168108
# iterations=4880000, n_solutions=21, min_steps=3864, max_got_keys=26/26, len(Q)=777282, killed_branches=9188805
# iterations=4890000, n_solutions=21, min_steps=3864, max_got_keys=26/26, len(Q)=770529, killed_branches=9208195
# iterations=4900000, n_solutions=21, min_steps=3864, max_got_keys=26/26, len(Q)=763671, killed_branches=9229079
# iterations=4910000, n_solutions=21, min_steps=3864, max_got_keys=26/26, len(Q)=759445, killed_branches=9248828
# iterations=4920000, n_solutions=21, min_steps=3864, max_got_keys=26/26, len(Q)=758193, killed_branches=9266856
# iterations=4930000, n_solutions=21, min_steps=3864, max_got_keys=26/26, len(Q)=758487, killed_branches=9284917
# iterations=4940000, n_solutions=21, min_steps=3864, max_got_keys=26/26, len(Q)=755107, killed_branches=9307562
# iterations=4950000, n_solutions=21, min_steps=3864, max_got_keys=26/26, len(Q)=754496, killed_branches=9325363
# iterations=4960000, n_solutions=21, min_steps=3864, max_got_keys=26/26, len(Q)=755127, killed_branches=9345201
# iterations=4970000, n_solutions=21, min_steps=3864, max_got_keys=26/26, len(Q)=751352, killed_branches=9365173
# iterations=4980000, n_solutions=21, min_steps=3864, max_got_keys=26/26, len(Q)=747284, killed_branches=9386553
# iterations=4990000, n_solutions=21, min_steps=3864, max_got_keys=26/26, len(Q)=742612, killed_branches=9409685
# iterations=5000000, n_solutions=21, min_steps=3864, max_got_keys=26/26, len(Q)=740027, killed_branches=9429742
# iterations=5010000, n_solutions=21, min_steps=3864, max_got_keys=26/26, len(Q)=739197, killed_branches=9447475
# iterations=5020000, n_solutions=21, min_steps=3864, max_got_keys=26/26, len(Q)=736698, killed_branches=9467756
# iterations=5030000, n_solutions=21, min_steps=3864, max_got_keys=26/26, len(Q)=733312, killed_branches=9490100
# iterations=5040000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=728480, killed_branches=9513828
# iterations=5050000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=721940, killed_branches=9541050
# iterations=5060000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=715795, killed_branches=9568731
# iterations=5070000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=708935, killed_branches=9594489
# iterations=5080000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=706453, killed_branches=9615142
# iterations=5090000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=705427, killed_branches=9633254
# iterations=5100000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=704712, killed_branches=9654118
# iterations=5110000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=701750, killed_branches=9675392
# iterations=5120000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=697530, killed_branches=9696011
# iterations=5130000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=696329, killed_branches=9714207
# iterations=5140000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=695168, killed_branches=9734903
# iterations=5150000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=693648, killed_branches=9754525
# iterations=5160000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=689224, killed_branches=9775209
# iterations=5170000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=685760, killed_branches=9794940
# iterations=5180000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=680073, killed_branches=9816616
# iterations=5190000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=673694, killed_branches=9838205
# iterations=5200000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=667745, killed_branches=9859472
# iterations=5210000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=661098, killed_branches=9882649
# iterations=5220000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=652626, killed_branches=9903781
# iterations=5230000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=647153, killed_branches=9925697
# iterations=5240000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=640749, killed_branches=9945475
# iterations=5250000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=637004, killed_branches=9964334
# iterations=5260000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=634638, killed_branches=9983054
# iterations=5270000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=631213, killed_branches=10002185
# iterations=5280000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=628298, killed_branches=10023569
# iterations=5290000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=624495, killed_branches=10045755
# iterations=5300000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=622101, killed_branches=10067862
# iterations=5310000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=618429, killed_branches=10089968
# iterations=5320000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=615206, killed_branches=10110018
# iterations=5330000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=610611, killed_branches=10131349
# iterations=5340000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=607296, killed_branches=10151471
# iterations=5350000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=602822, killed_branches=10170501
# iterations=5360000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=599963, killed_branches=10188073
# iterations=5370000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=597040, killed_branches=10205970
# iterations=5380000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=592387, killed_branches=10228717
# iterations=5390000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=586113, killed_branches=10257062
# iterations=5400000, n_solutions=22, min_steps=3864, max_got_keys=26/26, len(Q)=579852, killed_branches=10283853
# iterations=5410000, n_solutions=25, min_steps=3862, max_got_keys=26/26, len(Q)=572966, killed_branches=10309257
# iterations=5420000, n_solutions=25, min_steps=3862, max_got_keys=26/26, len(Q)=567613, killed_branches=10332313
# iterations=5430000, n_solutions=25, min_steps=3862, max_got_keys=26/26, len(Q)=563355, killed_branches=10352663
# iterations=5440000, n_solutions=25, min_steps=3862, max_got_keys=26/26, len(Q)=557918, killed_branches=10374087
# iterations=5450000, n_solutions=25, min_steps=3862, max_got_keys=26/26, len(Q)=552004, killed_branches=10396089
# iterations=5460000, n_solutions=25, min_steps=3862, max_got_keys=26/26, len(Q)=550554, killed_branches=10418207
# iterations=5470000, n_solutions=25, min_steps=3862, max_got_keys=26/26, len(Q)=545534, killed_branches=10438909
# iterations=5480000, n_solutions=25, min_steps=3862, max_got_keys=26/26, len(Q)=539989, killed_branches=10459490
# iterations=5490000, n_solutions=25, min_steps=3862, max_got_keys=26/26, len(Q)=534564, killed_branches=10481767
# iterations=5500000, n_solutions=25, min_steps=3862, max_got_keys=26/26, len(Q)=528094, killed_branches=10504170
# iterations=5510000, n_solutions=25, min_steps=3862, max_got_keys=26/26, len(Q)=521755, killed_branches=10524398
# iterations=5520000, n_solutions=25, min_steps=3862, max_got_keys=26/26, len(Q)=514974, killed_branches=10546216
# iterations=5530000, n_solutions=25, min_steps=3862, max_got_keys=26/26, len(Q)=508991, killed_branches=10571251
# iterations=5540000, n_solutions=25, min_steps=3862, max_got_keys=26/26, len(Q)=504078, killed_branches=10593276
# iterations=5550000, n_solutions=25, min_steps=3862, max_got_keys=26/26, len(Q)=498948, killed_branches=10613282
# iterations=5560000, n_solutions=25, min_steps=3862, max_got_keys=26/26, len(Q)=492486, killed_branches=10633947
# iterations=5570000, n_solutions=25, min_steps=3862, max_got_keys=26/26, len(Q)=485856, killed_branches=10655837
# iterations=5580000, n_solutions=25, min_steps=3862, max_got_keys=26/26, len(Q)=480391, killed_branches=10676018
# iterations=5590000, n_solutions=25, min_steps=3862, max_got_keys=26/26, len(Q)=473939, killed_branches=10699368
# iterations=5600000, n_solutions=25, min_steps=3862, max_got_keys=26/26, len(Q)=467443, killed_branches=10724685
# iterations=5610000, n_solutions=25, min_steps=3862, max_got_keys=26/26, len(Q)=463512, killed_branches=10744551
# iterations=5620000, n_solutions=25, min_steps=3862, max_got_keys=26/26, len(Q)=455360, killed_branches=10766160
# iterations=5630000, n_solutions=26, min_steps=3862, max_got_keys=26/26, len(Q)=446757, killed_branches=10787642
# iterations=5640000, n_solutions=26, min_steps=3862, max_got_keys=26/26, len(Q)=438674, killed_branches=10807398
# iterations=5650000, n_solutions=26, min_steps=3862, max_got_keys=26/26, len(Q)=430771, killed_branches=10827026
# iterations=5660000, n_solutions=26, min_steps=3862, max_got_keys=26/26, len(Q)=424134, killed_branches=10848401
# iterations=5670000, n_solutions=26, min_steps=3862, max_got_keys=26/26, len(Q)=416784, killed_branches=10869021
# iterations=5680000, n_solutions=26, min_steps=3862, max_got_keys=26/26, len(Q)=409553, killed_branches=10889119
# iterations=5690000, n_solutions=26, min_steps=3862, max_got_keys=26/26, len(Q)=400917, killed_branches=10912230
# iterations=5700000, n_solutions=27, min_steps=3862, max_got_keys=26/26, len(Q)=393156, killed_branches=10933557
# iterations=5710000, n_solutions=27, min_steps=3862, max_got_keys=26/26, len(Q)=384921, killed_branches=10954946
# iterations=5720000, n_solutions=27, min_steps=3862, max_got_keys=26/26, len(Q)=376862, killed_branches=10976296
# iterations=5730000, n_solutions=27, min_steps=3862, max_got_keys=26/26, len(Q)=368782, killed_branches=10997406
# iterations=5740000, n_solutions=27, min_steps=3862, max_got_keys=26/26, len(Q)=361536, killed_branches=11017981
# iterations=5750000, n_solutions=27, min_steps=3862, max_got_keys=26/26, len(Q)=355342, killed_branches=11038334
# iterations=5760000, n_solutions=27, min_steps=3862, max_got_keys=26/26, len(Q)=347175, killed_branches=11057232
# iterations=5770000, n_solutions=27, min_steps=3862, max_got_keys=26/26, len(Q)=338581, killed_branches=11075811
# iterations=5780000, n_solutions=27, min_steps=3862, max_got_keys=26/26, len(Q)=333098, killed_branches=11096247
# iterations=5790000, n_solutions=27, min_steps=3862, max_got_keys=26/26, len(Q)=328308, killed_branches=11115659
# iterations=5800000, n_solutions=27, min_steps=3862, max_got_keys=26/26, len(Q)=321937, killed_branches=11137069
# iterations=5810000, n_solutions=27, min_steps=3862, max_got_keys=26/26, len(Q)=315977, killed_branches=11158081
# iterations=5820000, n_solutions=27, min_steps=3862, max_got_keys=26/26, len(Q)=310107, killed_branches=11179356
# iterations=5830000, n_solutions=27, min_steps=3862, max_got_keys=26/26, len(Q)=302714, killed_branches=11200570
# iterations=5840000, n_solutions=27, min_steps=3862, max_got_keys=26/26, len(Q)=297148, killed_branches=11219916
# iterations=5850000, n_solutions=27, min_steps=3862, max_got_keys=26/26, len(Q)=291544, killed_branches=11239412
# iterations=5860000, n_solutions=29, min_steps=3862, max_got_keys=26/26, len(Q)=284498, killed_branches=11261350
# iterations=5870000, n_solutions=31, min_steps=3862, max_got_keys=26/26, len(Q)=276251, killed_branches=11286145
# iterations=5880000, n_solutions=31, min_steps=3862, max_got_keys=26/26, len(Q)=270607, killed_branches=11305881
# iterations=5890000, n_solutions=31, min_steps=3862, max_got_keys=26/26, len(Q)=265046, killed_branches=11328071
# iterations=5900000, n_solutions=31, min_steps=3862, max_got_keys=26/26, len(Q)=258034, killed_branches=11349274
# iterations=5910000, n_solutions=31, min_steps=3862, max_got_keys=26/26, len(Q)=252044, killed_branches=11369743
# iterations=5920000, n_solutions=31, min_steps=3862, max_got_keys=26/26, len(Q)=245810, killed_branches=11392193
# iterations=5930000, n_solutions=31, min_steps=3862, max_got_keys=26/26, len(Q)=239612, killed_branches=11412288
# iterations=5940000, n_solutions=31, min_steps=3862, max_got_keys=26/26, len(Q)=232428, killed_branches=11432589
# iterations=5950000, n_solutions=31, min_steps=3862, max_got_keys=26/26, len(Q)=224122, killed_branches=11453206
# iterations=5960000, n_solutions=31, min_steps=3862, max_got_keys=26/26, len(Q)=216649, killed_branches=11473315
# iterations=5970000, n_solutions=31, min_steps=3862, max_got_keys=26/26, len(Q)=210295, killed_branches=11493042
# iterations=5980000, n_solutions=31, min_steps=3862, max_got_keys=26/26, len(Q)=203807, killed_branches=11513056
# iterations=5990000, n_solutions=31, min_steps=3862, max_got_keys=26/26, len(Q)=196901, killed_branches=11534758
# iterations=6000000, n_solutions=31, min_steps=3862, max_got_keys=26/26, len(Q)=190559, killed_branches=11555011
# iterations=6010000, n_solutions=31, min_steps=3862, max_got_keys=26/26, len(Q)=183423, killed_branches=11575487
# iterations=6020000, n_solutions=31, min_steps=3862, max_got_keys=26/26, len(Q)=176013, killed_branches=11594277
# iterations=6030000, n_solutions=31, min_steps=3862, max_got_keys=26/26, len(Q)=170129, killed_branches=11612517
# iterations=6040000, n_solutions=31, min_steps=3862, max_got_keys=26/26, len(Q)=162099, killed_branches=11636290
# iterations=6050000, n_solutions=34, min_steps=3862, max_got_keys=26/26, len(Q)=154046, killed_branches=11658932
# iterations=6060000, n_solutions=34, min_steps=3862, max_got_keys=26/26, len(Q)=146466, killed_branches=11680491
# iterations=6070000, n_solutions=34, min_steps=3862, max_got_keys=26/26, len(Q)=139674, killed_branches=11703035
# iterations=6080000, n_solutions=34, min_steps=3862, max_got_keys=26/26, len(Q)=131881, killed_branches=11723742
# iterations=6090000, n_solutions=34, min_steps=3862, max_got_keys=26/26, len(Q)=123689, killed_branches=11744615
# iterations=6100000, n_solutions=34, min_steps=3862, max_got_keys=26/26, len(Q)=115961, killed_branches=11763885
# iterations=6110000, n_solutions=34, min_steps=3862, max_got_keys=26/26, len(Q)=107763, killed_branches=11784410
# iterations=6120000, n_solutions=34, min_steps=3862, max_got_keys=26/26, len(Q)=99536, killed_branches=11803697
# iterations=6130000, n_solutions=34, min_steps=3862, max_got_keys=26/26, len(Q)=90632, killed_branches=11822599
# iterations=6140000, n_solutions=34, min_steps=3862, max_got_keys=26/26, len(Q)=82015, killed_branches=11841825
# iterations=6150000, n_solutions=34, min_steps=3862, max_got_keys=26/26, len(Q)=74016, killed_branches=11861606
# iterations=6160000, n_solutions=34, min_steps=3862, max_got_keys=26/26, len(Q)=65595, killed_branches=11881244
# iterations=6170000, n_solutions=34, min_steps=3862, max_got_keys=26/26, len(Q)=57484, killed_branches=11900304
# iterations=6180000, n_solutions=34, min_steps=3862, max_got_keys=26/26, len(Q)=49046, killed_branches=11921150
# iterations=6190000, n_solutions=34, min_steps=3862, max_got_keys=26/26, len(Q)=40679, killed_branches=11941583
# iterations=6200000, n_solutions=34, min_steps=3862, max_got_keys=26/26, len(Q)=32207, killed_branches=11960272
# iterations=6210000, n_solutions=34, min_steps=3862, max_got_keys=26/26, len(Q)=23816, killed_branches=11977836
# iterations=6220000, n_solutions=34, min_steps=3862, max_got_keys=26/26, len(Q)=14837, killed_branches=11997476
# iterations=6230000, n_solutions=34, min_steps=3862, max_got_keys=26/26, len(Q)=5523, killed_branches=12015102
# Solution part 1 is: min_steps=3862 among n_solutions=34 with a total of iterations=6235886
